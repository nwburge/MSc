# %% [markdown]
# # ORAS5 Seasonal Cell-Year Classification (Inflection Study)
#
# This notebook builds on the earlier ORAS5 classification test, but instead of using basin-mean monthly values or annual values, it works with **seasonal values at every grid cell**.
#
# The aim is to see whether local ocean variables from ORAS5 can be used to distinguish between two climate regimes:
#
# 0 = before the threshold year
# 1 = after the threshold year
#
# The workflow is roughly:
#
# 1. Load and inspect the ORAS5 files
# 2. Build annual fields for each variable
# 3. Combine them into a single feature dataset
# 4. Convert the dataset into a machine-learning table
# 5. Train a classifier
# 6. Evaluate how well it separates the two regimes
# 7. Explore the data using correlations, distributions and trends
#
# For now the analysis is restricted to a smaller North Atlantic region to compare the result with the previous notebook.

# %% [markdown]
# ## Imports
#
# Import the packages needed for working with NetCDF files, data handling, plotting, and machine learning.

# %%
import warnings
warnings.filterwarnings("ignore")

from pathlib import Path
import re
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, RocCurveDisplay
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.inspection import permutation_importance

# %% [markdown]
# ## Data Setup
#
# Define the main settings used throughout the notebook:
#
# • the directory containing the ORAS5 boxed files
# • the study region
# • the year used to split the two regimes
# • a folder where plots will be saved
#
# A small helper function is also set up to keep track of plots produced in the notebook.

# %%
DATA_DIR = Path(r"C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\ORAS5\BOXED")

# Region
REGION = {
    "lat_min": 25,
    "lat_max": 45,
    "lon_min": -50,
    "lon_max": -30,
}

MAX_YEARS = None   # for fast testing

OUT_DIR = Path("meeting_outputs")
OUT_DIR.mkdir(exist_ok=True)

NOTEBOOK_NAME = "oras5_annual_cell_year_meeting_version"

PLOT_LOG = []

def save_and_register(fig, name, section, notes=""):
    path = OUT_DIR / f"{name}.png"
    fig.savefig(path, dpi=150, bbox_inches="tight")
    PLOT_LOG.append({
        "notebook": NOTEBOOK_NAME,
        "section": section,
        "plot_name": name,
        "path": str(path),
        "notes": notes,
    })
    print(f"Saved: {path}")

# %% [markdown]
# ## Variable Configuration
#
# Define which variables will be used as features in the model.
#
# For each variable I specify:
#
# • the token used to identify its files
# • whether the annual value should be calculated as a mean or sum
# • whether depth averaging is needed
#
# The variables included are:
#
# SST
# salinity
# potential temperature
# net heat flux
# zonal current
# meridional current

# %%
FILE_RE = re.compile(r"ORAS5_(\d{4})_(\d{2})_(.+?)_boxed\.nc$")

VAR_META = {
    "sst": {
        "token": "sst",
        "agg": "mean",
        "depth_mode": None,
        "kind": "scalar",
    },
    "salinity": {
        "token": "so_salinity",
        "agg": "mean",
        "depth_mode": "0_100m",
        "kind": "scalar",
    },
    "thetao": {
        "token": "thetao",
        "agg": "mean",
        "depth_mode": "0_100m",
        "kind": "scalar",
    },
    "qnet": {
        "token": "heat",
        "agg": "sum",
        "depth_mode": None,
        "kind": "scalar",
    },
    "u_current": {
        "token": "u",
        "agg": "mean",
        "depth_mode": "0_100m",
        "kind": "scalar",
    },
    "v_current": {
        "token": "v",
        "agg": "mean",
        "depth_mode": "0_100m",
        "kind": "scalar",
    },
}

# %% [markdown]
# ## Finding Files and Reading Dates
#
# These helper functions locate files for each variable and extract the year and month from the filenames.
#
# This information is later used to build the annual datasets.

# %%
def files_for_token(data_dir, token):
    all_nc = sorted(data_dir.rglob("*.nc"))
    out = [p for p in all_nc if FILE_RE.search(p.name) and token in p.name]
    return sorted(out)

def time_from_filename(path):
    m = FILE_RE.search(path.name)
    if m is None:
        raise ValueError(f"Filename does not match expected pattern: {path.name}")
    year = int(m.group(1))
    month = int(m.group(2))
    return pd.Timestamp(year=year, month=month, day=1)

# %% [markdown]
# ## Quick File Check
#
# Before doing anything heavy, check how many files are found for each variable token.
#
# This just confirms that the filename matching is working correctly.

# %%
for name, meta in VAR_META.items():
    if meta["kind"] == "scalar":
        paths = files_for_token(DATA_DIR, meta["token"])
        print(f"{name:15s} -> {len(paths)} files using token '{meta['token']}'")
        if len(paths) > 0:
            print("   first:", paths[0].name)
    else:
        upaths = files_for_token(DATA_DIR, meta["u_token"])
        vpaths = files_for_token(DATA_DIR, meta["v_token"])
        print(f"{name:15s} -> {len(upaths)} u-files ('{meta['u_token']}'), {len(vpaths)} v-files ('{meta['v_token']}')")
        if len(upaths) > 0:
            print("   u first:", upaths[0].name)
        if len(vpaths) > 0:
            print("   v first:", vpaths[0].name)
# Out:
# sst             -> 816 files using token 'sst'
#    first: ORAS5_1958_01_sst_boxed.nc
# salinity        -> 775 files using token 'so_salinity'
#    first: ORAS5_1958_01_so_salinity_boxed.nc
# thetao          -> 769 files using token 'thetao'
#    first: ORAS5_1958_01_thetao_potential_temperature_boxed.nc
# qnet            -> 775 files using token 'heat'
#    first: ORAS5_1958_01_net_downward_heat_flux_boxed.nc
# u_current       -> 2893 files using token 'u'
#    first: ORAS5_1958_01_net_downward_heat_flux_boxed.nc
# v_current       -> 1352 files using token 'v'
#    first: ORAS5_1958_01_meridional_velocity_boxed.nc

# %% [markdown]
# ## Inspecting Example Files
#
# Look at one example file for each variable to see:
#
# • variable names
# • coordinate names
# • dataset dimensions
#
# ORAS5 files sometimes use slightly different dimension names, so this step helps avoid problems later.

# %%
def inspect_file(path):
    with xr.open_dataset(path) as ds:
        print(f"\nFILE: {path.name}")
        print("dims:", dict(ds.dims))
        print("coords:", list(ds.coords))
        print("data_vars:", list(ds.data_vars))
        for name in list(ds.data_vars)[:5]:
            da = ds[name]
            print(f"  {name}: dims={da.dims}, shape={da.shape}")

for name, meta in VAR_META.items():
    if meta["kind"] == "scalar":
        paths = files_for_token(DATA_DIR, meta["token"])
        if paths:
            inspect_file(paths[0])
    else:
        upaths = files_for_token(DATA_DIR, meta["u_token"])
        vpaths = files_for_token(DATA_DIR, meta["v_token"])
        if upaths:
            inspect_file(upaths[0])
        if vpaths:
            inspect_file(vpaths[0])
# Out:
# FILE: ORAS5_1958_01_sst_boxed.nc
# dims: {'time_counter': 1, 'y': 522, 'x': 363}
# coords: ['nav_lat', 'nav_lon', 'time_counter']
# data_vars: ['sosstsst']
#   sosstsst: dims=('time_counter', 'y', 'x'), shape=(1, 522, 363)
#
# FILE: ORAS5_1958_01_so_salinity_boxed.nc
# dims: {'time_counter': 1, 'deptht': 75, 'y': 522, 'x': 363}
# coords: ['deptht', 'nav_lat', 'nav_lon', 'time_counter']
# data_vars: ['vosaline']
#   vosaline: dims=('time_counter', 'deptht', 'y', 'x'), shape=(1, 75, 522, 363)
#
# FILE: ORAS5_1958_01_thetao_potential_temperature_boxed.nc
# dims: {'time_counter': 1, 'deptht': 75, 'y': 522, 'x': 363}
# coords: ['deptht', 'nav_lat', 'nav_lon', 'time_counter']
# data_vars: ['votemper']
#   votemper: dims=('time_counter', 'deptht', 'y', 'x'), shape=(1, 75, 522, 363)
#
# FILE: ORAS5_1958_01_net_downward_heat_flux_boxed.nc
# dims: {'time_counter': 1, 'y': 522, 'x': 363}
# coords: ['nav_lat', 'nav_lon', 'time_counter']
# data_vars: ['sohefldo']
#   sohefldo: dims=('time_counter', 'y', 'x'), shape=(1, 522, 363)
#
# FILE: ORAS5_1958_01_net_downward_heat_flux_boxed.nc
# dims: {'time_counter': 1, 'y': 522, 'x': 363}
# coords: ['nav_lat', 'nav_lon', 'time_counter']
# data_vars: ['sohefldo']
#   sohefldo: dims=('time_counter', 'y', 'x'), shape=(1, 522, 363)
#
# FILE: ORAS5_1958_01_meridional_velocity_boxed.nc
# dims: {'time_counter': 1, 'depthv': 75, 'y': 523, 'x': 364}
# coords: ['depthv', 'nav_lat', 'nav_lon', 'time_counter']
# data_vars: ['vomecrty']
#   vomecrty: dims=('time_counter', 'depthv', 'y', 'x'), shape=(1, 75, 523, 364)

# %% [markdown]
# ## Helper Functions
#
# Define several small functions used later when building the datasets.
#
# These handle:
#
# • identifying the main variable in a file
# • finding coordinate names
# • subsetting the region
# • handling depth dimensions
# • standardising time coordinates

# %%
def find_main_var(ds):
    ignore = {
        "time", "time_counter", "valid_time", "nav_time",
        "lat", "lon", "latitude", "longitude", "nav_lat", "nav_lon",
        "depth", "deptht", "depthu", "depthv", "nav_lev"
    }
    candidates = [k for k in ds.data_vars if k not in ignore]
    if len(candidates) == 0:
        raise ValueError(f"No usable data variable found. data_vars={list(ds.data_vars)}")
    return candidates[0]

def find_coord_name(ds, options):
    for name in options:
        if name in ds.coords or name in ds.variables:
            return name
    return None

def normalise_longitude(lon):
    return xr.where(lon > 180, lon - 360, lon)

def subset_region(ds, region):
    lat_name = find_coord_name(ds, ["lat", "latitude", "nav_lat"])
    lon_name = find_coord_name(ds, ["lon", "longitude", "nav_lon"])

    if lat_name is None or lon_name is None:
        print("Warning: could not find lat/lon coords; skipping regional subset")
        return ds

    lat = ds[lat_name]
    lon = ds[lon_name]
    lon = normalise_longitude(lon)

    if lon_name in ds.coords:
        ds = ds.assign_coords({lon_name: lon})

    mask = (
        (lat >= region["lat_min"]) & (lat <= region["lat_max"]) &
        (lon >= region["lon_min"]) & (lon <= region["lon_max"])
    )
    return ds.where(mask, drop=True)

def depth_reduce_if_needed(da, ds, depth_mode):
    if depth_mode is None:
        return da

    for zname in ["depth", "deptht", "depthu", "depthv", "nav_lev"]:
        if zname in da.dims:
            # Try to get the depth coordinate from the DataArray first
            if zname in da.coords:
                z = da[zname]
            elif zname in ds.coords:
                z = ds[zname]
            elif zname in ds.variables:
                z = ds[zname]
            else:
                # if the dim exists but no coord is found then fallback to index positions
                z = xr.DataArray(np.arange(da.sizes[zname]), dims=[zname], coords={zname: np.arange(da.sizes[zname])})

            if depth_mode == "0_100m":
                da = da.where((z >= 0) & (z <= 100), drop=True).mean(dim=zname)
                return da

    return da

def rename_time_dim_if_needed(da):
    for old in ["time_counter", "valid_time", "nav_time"]:
        if old in da.dims:
            return da.rename({old: "time"})
    return da

def add_time_coord(da, tstamp):
    if "time" in da.dims:
        da = da.assign_coords(time=[np.datetime64(tstamp)])
    else:
        da = da.expand_dims(time=[np.datetime64(tstamp)])
    return da

def get_spatial_dims(da):
    return [d for d in da.dims if d != "time"]

# %% [markdown]
# ## Season Definitions
#
# To move from annual features to seasonal ones, I first define the four seasons:
# - DJF
# - MAM
# - JJA
# - SON
#
# A small helper function is then used to assign each monthly file to both:
# - a season label
# - a season-year
#
# For DJF, December is assigned to the following year.
# This means, for example, that December 1984 is grouped with January and February 1985 to form DJF 1985.
#
# If the previous December is not available, the DJF mean is still calculated using the January and February values that are present.

# %%
SEASON_ORDER = ["DJF", "MAM", "JJA", "SON"]

def month_to_season_year(ts):
    y = ts.year
    m = ts.month

    if m == 12:
        return "DJF", y + 1
    elif m in [1, 2]:
        return "DJF", y
    elif m in [3, 4, 5]:
        return "MAM", y
    elif m in [6, 7, 8]:
        return "JJA", y
    elif m in [9, 10, 11]:
        return "SON", y
    else:
        raise ValueError(f"Unexpected month: {m}")

# %% [markdown]
# ## Building Seasonal Fields
#
# This function creates four seasonal gridded fields for a given variable:
# - variable_DJF
# - variable_MAM
# - variable_JJA
# - variable_SON
#
# For each monthly file it:
# 1. Opens the dataset
# 2. Extracts the variable
# 3. Applies depth averaging if required
# 4. Subsets the study region
# 5. Assigns the file to a season and season-year
#
# The monthly data is then grouped by season and averaged to form seasonal values.

# %%
def build_seasonal_scalar_fields(data_dir, var_name, meta, region, max_years=None):
    paths = files_for_token(data_dir, meta["token"])
    if len(paths) == 0:
        raise FileNotFoundError(f"No files found for {var_name} with token '{meta['token']}'")

    if max_years is not None:
        season_years_seen = sorted({
            month_to_season_year(time_from_filename(p))[1]
            for p in paths
        })[:max_years]
        paths = [
            p for p in paths
            if month_to_season_year(time_from_filename(p))[1] in season_years_seen
        ]

    monthly_arrays = []

    for i, p in enumerate(paths, start=1):
        if i == 1 or i % 25 == 0 or i == len(paths):
            print(f"[{var_name}] {i}/{len(paths)} {p.name}")

        tstamp = time_from_filename(p)
        season, season_year = month_to_season_year(tstamp)

        with xr.open_dataset(p) as ds:
            ds = subset_region(ds, region)
            vname = find_main_var(ds)
            da = ds[vname]

            da = depth_reduce_if_needed(da, ds, meta["depth_mode"])
            da = rename_time_dim_if_needed(da)

            if "time" in da.dims and da.sizes["time"] == 1:
                da = da.isel(time=0, drop=True)

            da = da.squeeze(drop=True)

            monthly_arrays.append({
                "timestamp": tstamp,
                "season": season,
                "season_year": season_year,
                "array": da.load()
            })

    if len(monthly_arrays) == 0:
        raise ValueError(f"No monthly arrays built for {var_name}")

    common_dims = list(monthly_arrays[0]["array"].dims)
    for item in monthly_arrays[1:]:
        da = item["array"]
        common_dims = [d for d in common_dims if d in da.dims]

    if len(common_dims) == 0:
        raise ValueError(f"No common dims found across monthly arrays for {var_name}")

    cleaned = []
    for item in monthly_arrays:
        da = item["array"]

        # Remove bounds dimension if present
        if "bnds" in da.dims:
            da = da.isel(bnds=0, drop=True)

        # Remove stray coordinates
        da = da.reset_coords(drop=True)

        extra_dims = [d for d in da.dims if d not in common_dims]

        for d in extra_dims:
            if da.sizes[d] == 1:
                da = da.isel({d: 0}, drop=True)
            else:
                raise ValueError(
                    f"{var_name} file at {item['timestamp']} has non-singleton extra dim '{d}' "
                    f"with size {da.sizes[d]} and dims {da.dims}"
                )

        da = da.squeeze(drop=True)
        da = da.transpose(*common_dims, ...)
        item2 = item.copy()
        item2["array"] = da
        cleaned.append(item2)

    min_sizes = {
        d: min(item["array"].sizes[d] for item in cleaned)
        for d in common_dims
    }

    fixed = []
    for item in cleaned:
        da = item["array"]

        indexers = {d: slice(0, min_sizes[d]) for d in common_dims}
        da = da.isel(**indexers)

        da = da.assign_coords({d: np.arange(min_sizes[d]) for d in common_dims})

        drop_coords = [c for c in da.coords if c not in common_dims]

        if len(drop_coords) > 0:
            da = da.drop_vars(drop_coords, errors="ignore")

        da = da.squeeze(drop=True)
        da = da.transpose(*common_dims, ...)

        # Force pure numeric array and strip problematic coords
        da = xr.DataArray(
            da.values.astype(np.float32),
            dims=da.dims,
            coords={d: da.coords[d] for d in da.dims if d in da.coords}
        )

        item2 = item.copy()
        item2["array"] = da
        fixed.append(item2)

    grouped = {}
    for item in fixed:
        key = (item["season_year"], item["season"])
        grouped.setdefault(key, []).append(item["array"])

    seasonal_fields = {}

    for season in SEASON_ORDER:
        season_arrays = []

        valid_years = sorted({k[0] for k in grouped if k[1] == season})
        if max_years is not None:
            valid_years = valid_years[:max_years]

        for year in valid_years:
            arrs = grouped.get((year, season), [])

            if len(arrs) == 0:
                continue

            da_season = xr.concat(arrs, dim="time").mean("time")
            da_season = da_season.expand_dims(year=[year])
            season_arrays.append(da_season)

        if len(season_arrays) == 0:
            print(f"Warning: no seasonal arrays built for {var_name}_{season}")
            continue

        out = xr.concat(
            season_arrays,
            dim="year",
            coords="minimal",
            compat="override",
            join="override"
        )
        out.name = f"{var_name}_{season}"
        seasonal_fields[f"{var_name}_{season}"] = out

    return seasonal_fields

# %% [markdown]
# ## Building the Seasonal Feature Fields
#
# Loop through the selected variables and build the seasonal field for each one.
#
# Instead of producing one annual field per variable, this now produces four seasonal fields per variable.
# With six variables this gives a total of 24 feature fields.
#
# To make debugging easier, the notebook still starts with the meridional current before processing the remaining variables.

# %%
seasonal_fields = {}

build_order = []
if "v_current" in VAR_META:
    build_order.append("v_current")
build_order += [name for name in VAR_META.keys() if name != "v_current"]

print("Build order:", build_order)

for var_name in build_order:
    meta = VAR_META[var_name]
    print(f"\n=== Building seasonal fields for {var_name} ===")

    var_seasonal = build_seasonal_scalar_fields(
        DATA_DIR, var_name, meta, REGION, max_years=MAX_YEARS
    )

    seasonal_fields.update(var_seasonal)

    for k, da in var_seasonal.items():
        print(k, da.shape, da.dims)
# Out:
# Build order: ['v_current', 'sst', 'salinity', 'thetao', 'qnet', 'u_current']
#
# === Building seasonal fields for v_current ===
# [v_current] 1/1352 ORAS5_1958_01_meridional_velocity_boxed.nc
# [v_current] 25/1352 ORAS5_1959_11_v_meridional_boxed.nc
# [v_current] 50/1352 ORAS5_1961_12_v_meridional_boxed.nc
# [v_current] 75/1352 ORAS5_1964_01_v_meridional_boxed.nc
# [v_current] 100/1352 ORAS5_1966_02_v_meridional_boxed.nc
# [v_current] 125/1352 ORAS5_1968_03_v_meridional_boxed.nc
# [v_current] 150/1352 ORAS5_1970_04_v_meridional_boxed.nc
# [v_current] 175/1352 ORAS5_1972_05_v_meridional_boxed.nc
# [v_current] 200/1352 ORAS5_1974_06_v_meridional_boxed.nc
# [v_current] 225/1352 ORAS5_1975_10_v_meridional_boxed.nc
# [v_current] 250/1352 ORAS5_1976_10_v_rotated_boxed.nc
# [v_current] 275/1352 ORAS5_1977_11_v_meridional_boxed.nc
# [v_current] 300/1352 ORAS5_1978_11_v_rotated_boxed.nc
# Warning: could not find lat/lon coords; skipping regional subset
# [v_current] 325/1352 ORAS5_1979_12_v_meridional_boxed.nc
# [v_current] 350/1352 ORAS5_1980_12_v_rotated_boxed.nc
# [v_current] 375/1352 ORAS5_1982_01_v_meridional_boxed.nc
# [v_current] 400/1352 ORAS5_1983_01_v_rotated_boxed.nc
# [v_current] 425/1352 ORAS5_1984_02_v_meridional_boxed.nc
# [v_current] 450/1352 ORAS5_1985_02_v_rotated_boxed.nc
# [v_current] 475/1352 ORAS5_1986_03_v_meridional_boxed.nc
# [v_current] 500/1352 ORAS5_1987_03_v_rotated_boxed.nc
# [v_current] 525/1352 ORAS5_1988_04_v_meridional_boxed.nc
# [v_current] 550/1352 ORAS5_1989_04_v_rotated_boxed.nc
# [v_current] 575/1352 ORAS5_1990_05_v_meridional_boxed.nc
# [v_current] 600/1352 ORAS5_1991_05_v_rotated_boxed.nc
# [v_current] 625/1352 ORAS5_1992_06_v_meridional_boxed.nc
# [v_current] 650/1352 ORAS5_1993_06_v_rotated_boxed.nc
# [v_current] 675/1352 ORAS5_1994_07_v_meridional_boxed.nc
# [v_current] 700/1352 ORAS5_1995_07_v_rotated_boxed.nc
# [v_current] 725/1352 ORAS5_1996_08_v_meridional_boxed.nc
# [v_current] 750/1352 ORAS5_1997_08_v_rotated_boxed.nc
# [v_current] 775/1352 ORAS5_1998_09_v_meridional_boxed.nc
# [v_current] 800/1352 ORAS5_1999_09_v_rotated_boxed.nc
# [v_current] 825/1352 ORAS5_2000_10_v_meridional_boxed.nc
# [v_current] 850/1352 ORAS5_2001_10_v_rotated_boxed.nc
# [v_current] 875/1352 ORAS5_2002_11_v_meridional_boxed.nc
# [v_current] 900/1352 ORAS5_2003_11_v_rotated_boxed.nc
# [v_current] 925/1352 ORAS5_2004_12_v_meridional_boxed.nc
# [v_current] 950/1352 ORAS5_2005_12_v_rotated_boxed.nc
# [v_current] 975/1352 ORAS5_2007_01_v_meridional_boxed.nc
# [v_current] 1000/1352 ORAS5_2008_01_v_rotated_boxed.nc
# [v_current] 1025/1352 ORAS5_2009_02_v_meridional_boxed.nc
# [v_current] 1050/1352 ORAS5_2010_02_v_rotated_boxed.nc
# [v_current] 1075/1352 ORAS5_2011_03_v_meridional_boxed.nc
# [v_current] 1100/1352 ORAS5_2012_03_v_rotated_boxed.nc
# [v_current] 1125/1352 ORAS5_2013_04_v_meridional_boxed.nc
# [v_current] 1150/1352 ORAS5_2014_04_v_rotated_boxed.nc
# [v_current] 1175/1352 ORAS5_2015_05_v_meridional_boxed.nc
# [v_current] 1200/1352 ORAS5_2016_05_v_rotated_boxed.nc
# [v_current] 1225/1352 ORAS5_2017_06_v_meridional_boxed.nc
# [v_current] 1250/1352 ORAS5_2018_06_v_rotated_boxed.nc
# [v_current] 1275/1352 ORAS5_2019_07_v_meridional_boxed.nc
# [v_current] 1300/1352 ORAS5_2020_07_v_rotated_boxed.nc
# [v_current] 1325/1352 ORAS5_2024_11_v_meridional_boxed.nc
# [v_current] 1350/1352 ORAS5_2025_11_v_rotated_boxed.nc
# [v_current] 1352/1352 ORAS5_2025_12_v_rotated_boxed.nc
# v_current_DJF (66, 99, 80) ('year', 'y', 'x')
# v_current_MAM (65, 99, 80) ('year', 'y', 'x')
# v_current_JJA (65, 99, 80) ('year', 'y', 'x')
# v_current_SON (65, 99, 80) ('year', 'y', 'x')
#
# === Building seasonal fields for sst ===
# [sst] 1/816 ORAS5_1958_01_sst_boxed.nc
# [sst] 25/816 ORAS5_1960_01_sst_boxed.nc
# [sst] 50/816 ORAS5_1962_02_sst_boxed.nc
# [sst] 75/816 ORAS5_1964_03_sst_boxed.nc
# [sst] 100/816 ORAS5_1966_04_sst_boxed.nc
# [sst] 125/816 ORAS5_1968_05_sst_boxed.nc
# [sst] 150/816 ORAS5_1970_06_sst_boxed.nc
# [sst] 175/816 ORAS5_1972_07_sst_boxed.nc
# [sst] 200/816 ORAS5_1974_08_sst_boxed.nc
# [sst] 225/816 ORAS5_1976_09_sst_boxed.nc
# [sst] 250/816 ORAS5_1978_10_sst_boxed.nc
# [sst] 275/816 ORAS5_1980_11_sst_boxed.nc
# [sst] 300/816 ORAS5_1982_12_sst_boxed.nc
# [sst] 325/816 ORAS5_1985_01_sst_boxed.nc
# [sst] 350/816 ORAS5_1987_02_sst_boxed.nc
# [sst] 375/816 ORAS5_1989_03_sst_boxed.nc
# [sst] 400/816 ORAS5_1991_04_sst_boxed.nc
# [sst] 425/816 ORAS5_1993_05_sst_boxed.nc
# [sst] 450/816 ORAS5_1995_06_sst_boxed.nc
# [sst] 475/816 ORAS5_1997_07_sst_boxed.nc
# [sst] 500/816 ORAS5_1999_08_sst_boxed.nc
# [sst] 525/816 ORAS5_2001_09_sst_boxed.nc
# [sst] 550/816 ORAS5_2003_10_sst_boxed.nc
# [sst] 575/816 ORAS5_2005_11_sst_boxed.nc
# [sst] 600/816 ORAS5_2007_12_sst_boxed.nc
# [sst] 625/816 ORAS5_2010_01_sst_boxed.nc
# [sst] 650/816 ORAS5_2012_02_sst_boxed.nc
# [sst] 675/816 ORAS5_2014_03_sst_boxed.nc
# [sst] 700/816 ORAS5_2016_04_sst_boxed.nc
# [sst] 725/816 ORAS5_2018_05_sst_boxed.nc
# [sst] 750/816 ORAS5_2020_06_sst_boxed.nc
# [sst] 775/816 ORAS5_2022_07_sst_boxed.nc
# [sst] 800/816 ORAS5_2024_08_sst_boxed.nc
# [sst] 816/816 ORAS5_2025_12_sst_boxed.nc
# sst_DJF (69, 99, 80) ('year', 'y', 'x')
# sst_MAM (68, 99, 80) ('year', 'y', 'x')
# sst_JJA (68, 99, 80) ('year', 'y', 'x')
# sst_SON (68, 99, 80) ('year', 'y', 'x')
#
# === Building seasonal fields for salinity ===
# [salinity] 1/775 ORAS5_1958_01_so_salinity_boxed.nc
# [salinity] 25/775 ORAS5_1960_01_so_salinity_boxed.nc
# [salinity] 50/775 ORAS5_1962_02_so_salinity_boxed.nc
# [salinity] 75/775 ORAS5_1964_03_so_salinity_boxed.nc
# [salinity] 100/775 ORAS5_1966_04_so_salinity_boxed.nc
# [salinity] 125/775 ORAS5_1968_05_so_salinity_boxed.nc
# [salinity] 150/775 ORAS5_1970_06_so_salinity_boxed.nc
# [salinity] 175/775 ORAS5_1972_07_so_salinity_boxed.nc
# [salinity] 200/775 ORAS5_1974_08_so_salinity_boxed.nc
# [salinity] 225/775 ORAS5_1976_09_so_salinity_boxed.nc
# [salinity] 250/775 ORAS5_1978_10_so_salinity_boxed.nc
# [salinity] 275/775 ORAS5_1980_11_so_salinity_boxed.nc
# [salinity] 300/775 ORAS5_1982_12_so_salinity_boxed.nc
# [salinity] 325/775 ORAS5_1985_01_so_salinity_boxed.nc
# [salinity] 350/775 ORAS5_1987_02_so_salinity_boxed.nc
# [salinity] 375/775 ORAS5_1989_03_so_salinity_boxed.nc
# [salinity] 400/775 ORAS5_1991_04_so_salinity_boxed.nc
# [salinity] 425/775 ORAS5_1993_05_so_salinity_boxed.nc
# [salinity] 450/775 ORAS5_1995_06_so_salinity_boxed.nc
# [salinity] 475/775 ORAS5_1997_07_so_salinity_boxed.nc
# [salinity] 500/775 ORAS5_1999_08_so_salinity_boxed.nc
# [salinity] 525/775 ORAS5_2001_09_so_salinity_boxed.nc
# [salinity] 550/775 ORAS5_2003_10_so_salinity_boxed.nc
# [salinity] 575/775 ORAS5_2005_11_so_salinity_boxed.nc
# [salinity] 600/775 ORAS5_2007_12_so_salinity_boxed.nc
# [salinity] 625/775 ORAS5_2010_01_so_salinity_boxed.nc
# [salinity] 650/775 ORAS5_2012_02_so_salinity_boxed.nc
# [salinity] 675/775 ORAS5_2014_03_so_salinity_boxed.nc
# [salinity] 700/775 ORAS5_2016_04_so_salinity_boxed.nc
# [salinity] 725/775 ORAS5_2018_05_so_salinity_boxed.nc
# [salinity] 750/775 ORAS5_2020_06_so_salinity_boxed.nc
# [salinity] 775/775 ORAS5_2025_12_so_salinity_boxed.nc
# salinity_DJF (66, 99, 80) ('year', 'y', 'x')
# salinity_MAM (64, 99, 80) ('year', 'y', 'x')
# salinity_JJA (65, 99, 80) ('year', 'y', 'x')
# salinity_SON (65, 99, 80) ('year', 'y', 'x')
#
# === Building seasonal fields for thetao ===
# [thetao] 1/769 ORAS5_1958_01_thetao_potential_temperature_boxed.nc
# [thetao] 25/769 ORAS5_1960_01_thetao_potential_temperature_boxed.nc
# [thetao] 50/769 ORAS5_1962_02_thetao_potential_temperature_boxed.nc
# [thetao] 75/769 ORAS5_1964_03_thetao_potential_temperature_boxed.nc
# [thetao] 100/769 ORAS5_1966_04_thetao_potential_temperature_boxed.nc
# [thetao] 125/769 ORAS5_1968_05_thetao_potential_temperature_boxed.nc
# [thetao] 150/769 ORAS5_1970_06_thetao_potential_temperature_boxed.nc
# [thetao] 175/769 ORAS5_1972_07_thetao_potential_temperature_boxed.nc
# [thetao] 200/769 ORAS5_1974_08_thetao_potential_temperature_boxed.nc
# [thetao] 225/769 ORAS5_1976_09_thetao_potential_temperature_boxed.nc
# [thetao] 250/769 ORAS5_1978_10_thetao_potential_temperature_boxed.nc
# [thetao] 275/769 ORAS5_1980_11_thetao_potential_temperature_boxed.nc
# [thetao] 300/769 ORAS5_1982_12_thetao_potential_temperature_boxed.nc
# [thetao] 325/769 ORAS5_1985_01_thetao_potential_temperature_boxed.nc
# [thetao] 350/769 ORAS5_1987_02_thetao_potential_temperature_boxed.nc
# [thetao] 375/769 ORAS5_1989_03_thetao_potential_temperature_boxed.nc
# [thetao] 400/769 ORAS5_1991_04_thetao_potential_temperature_boxed.nc
# [thetao] 425/769 ORAS5_1993_05_thetao_potential_temperature_boxed.nc
# [thetao] 450/769 ORAS5_1995_06_thetao_potential_temperature_boxed.nc
# [thetao] 475/769 ORAS5_1997_07_thetao_potential_temperature_boxed.nc
# [thetao] 500/769 ORAS5_1999_08_thetao_potential_temperature_boxed.nc
# [thetao] 525/769 ORAS5_2001_09_thetao_potential_temperature_boxed.nc
# [thetao] 550/769 ORAS5_2003_10_thetao_potential_temperature_boxed.nc
# [thetao] 575/769 ORAS5_2005_11_thetao_potential_temperature_boxed.nc
# [thetao] 600/769 ORAS5_2007_12_thetao_potential_temperature_boxed.nc
# [thetao] 625/769 ORAS5_2010_01_thetao_potential_temperature_boxed.nc
# [thetao] 650/769 ORAS5_2012_02_thetao_potential_temperature_boxed.nc
# [thetao] 675/769 ORAS5_2014_03_thetao_potential_temperature_boxed.nc
# [thetao] 700/769 ORAS5_2016_04_thetao_potential_temperature_boxed.nc
# [thetao] 725/769 ORAS5_2018_05_thetao_potential_temperature_boxed.nc
# [thetao] 750/769 ORAS5_2020_06_thetao_potential_temperature_boxed.nc
# [thetao] 769/769 ORAS5_2025_06_thetao_potential_temperature_boxed.nc
# thetao_DJF (65, 99, 80) ('year', 'y', 'x')
# thetao_MAM (64, 99, 80) ('year', 'y', 'x')
# thetao_JJA (65, 99, 80) ('year', 'y', 'x')
# thetao_SON (64, 99, 80) ('year', 'y', 'x')
#
# === Building seasonal fields for qnet ===
# [qnet] 1/775 ORAS5_1958_01_net_downward_heat_flux_boxed.nc
# [qnet] 25/775 ORAS5_1960_01_net_downward_heat_flux_boxed.nc
# [qnet] 50/775 ORAS5_1962_02_net_downward_heat_flux_boxed.nc
# [qnet] 75/775 ORAS5_1964_03_net_downward_heat_flux_boxed.nc
# [qnet] 100/775 ORAS5_1966_04_net_downward_heat_flux_boxed.nc
# [qnet] 125/775 ORAS5_1968_05_net_downward_heat_flux_boxed.nc
# [qnet] 150/775 ORAS5_1970_06_net_downward_heat_flux_boxed.nc
# [qnet] 175/775 ORAS5_1972_07_net_downward_heat_flux_boxed.nc
# [qnet] 200/775 ORAS5_1974_08_net_downward_heat_flux_boxed.nc
# [qnet] 225/775 ORAS5_1976_09_net_downward_heat_flux_boxed.nc
# [qnet] 250/775 ORAS5_1978_10_net_downward_heat_flux_boxed.nc
# [qnet] 275/775 ORAS5_1980_11_net_downward_heat_flux_boxed.nc
# [qnet] 300/775 ORAS5_1982_12_net_downward_heat_flux_boxed.nc
# [qnet] 325/775 ORAS5_1985_01_net_downward_heat_flux_boxed.nc
# [qnet] 350/775 ORAS5_1987_02_net_downward_heat_flux_boxed.nc
# [qnet] 375/775 ORAS5_1989_03_net_downward_heat_flux_boxed.nc
# [qnet] 400/775 ORAS5_1991_04_net_downward_heat_flux_boxed.nc
# [qnet] 425/775 ORAS5_1993_05_net_downward_heat_flux_boxed.nc
# [qnet] 450/775 ORAS5_1995_06_net_downward_heat_flux_boxed.nc
# [qnet] 475/775 ORAS5_1997_07_net_downward_heat_flux_boxed.nc
# [qnet] 500/775 ORAS5_1999_08_net_downward_heat_flux_boxed.nc
# [qnet] 525/775 ORAS5_2001_09_net_downward_heat_flux_boxed.nc
# [qnet] 550/775 ORAS5_2003_10_net_downward_heat_flux_boxed.nc
# [qnet] 575/775 ORAS5_2005_11_net_downward_heat_flux_boxed.nc
# [qnet] 600/775 ORAS5_2007_12_net_downward_heat_flux_boxed.nc
# [qnet] 625/775 ORAS5_2010_01_net_downward_heat_flux_boxed.nc
# [qnet] 650/775 ORAS5_2012_02_net_downward_heat_flux_boxed.nc
# [qnet] 675/775 ORAS5_2014_03_net_downward_heat_flux_boxed.nc
# [qnet] 700/775 ORAS5_2016_04_net_downward_heat_flux_boxed.nc
# [qnet] 725/775 ORAS5_2018_05_net_downward_heat_flux_boxed.nc
# [qnet] 750/775 ORAS5_2020_06_net_downward_heat_flux_boxed.nc
# [qnet] 775/775 ORAS5_2025_12_net_downward_heat_flux_boxed.nc
# qnet_DJF (66, 99, 80) ('year', 'y', 'x')
# qnet_MAM (64, 99, 80) ('year', 'y', 'x')
# qnet_JJA (65, 99, 80) ('year', 'y', 'x')
# qnet_SON (65, 99, 80) ('year', 'y', 'x')
#
# === Building seasonal fields for u_current ===
# [u_current] 1/2893 ORAS5_1958_01_net_downward_heat_flux_boxed.nc
# [u_current] 25/2893 ORAS5_1958_09_net_downward_heat_flux_boxed.nc
# [u_current] 50/2893 ORAS5_1959_05_thetao_potential_temperature_boxed.nc
# [u_current] 75/2893 ORAS5_1960_01_u_zonal_boxed.nc
# [u_current] 100/2893 ORAS5_1960_10_net_downward_heat_flux_boxed.nc
# [u_current] 125/2893 ORAS5_1961_06_thetao_potential_temperature_boxed.nc
# [u_current] 150/2893 ORAS5_1962_02_u_zonal_boxed.nc
# [u_current] 175/2893 ORAS5_1962_11_net_downward_heat_flux_boxed.nc
# [u_current] 200/2893 ORAS5_1963_07_thetao_potential_temperature_boxed.nc
# [u_current] 225/2893 ORAS5_1964_03_u_zonal_boxed.nc
# [u_current] 250/2893 ORAS5_1964_12_net_downward_heat_flux_boxed.nc
# [u_current] 275/2893 ORAS5_1965_08_thetao_potential_temperature_boxed.nc
# [u_current] 300/2893 ORAS5_1966_04_u_zonal_boxed.nc
# [u_current] 325/2893 ORAS5_1967_01_net_downward_heat_flux_boxed.nc
# [u_current] 350/2893 ORAS5_1967_09_thetao_potential_temperature_boxed.nc
# [u_current] 375/2893 ORAS5_1968_05_u_zonal_boxed.nc
# [u_current] 400/2893 ORAS5_1969_02_net_downward_heat_flux_boxed.nc
# [u_current] 425/2893 ORAS5_1969_10_thetao_potential_temperature_boxed.nc
# [u_current] 450/2893 ORAS5_1970_06_u_zonal_boxed.nc
# [u_current] 475/2893 ORAS5_1971_03_net_downward_heat_flux_boxed.nc
# [u_current] 500/2893 ORAS5_1971_11_thetao_potential_temperature_boxed.nc
# [u_current] 525/2893 ORAS5_1972_07_u_zonal_boxed.nc
# [u_current] 550/2893 ORAS5_1973_04_net_downward_heat_flux_boxed.nc
# [u_current] 575/2893 ORAS5_1973_12_thetao_potential_temperature_boxed.nc
# [u_current] 600/2893 ORAS5_1974_08_u_zonal_boxed.nc
# [u_current] 625/2893 ORAS5_1975_04_net_downward_heat_flux_boxed.nc
# [u_current] 650/2893 ORAS5_1975_10_thetao_potential_temperature_boxed.nc
# [u_current] 675/2893 ORAS5_1976_04_u_rotated_boxed.nc
# [u_current] 700/2893 ORAS5_1976_10_u_zonal_boxed.nc
# [u_current] 725/2893 ORAS5_1977_05_net_downward_heat_flux_boxed.nc
# [u_current] 750/2893 ORAS5_1977_11_thetao_potential_temperature_boxed.nc
# [u_current] 775/2893 ORAS5_1978_05_u_rotated_boxed.nc
# [u_current] 800/2893 ORAS5_1978_11_u_zonal_boxed.nc
# [u_current] 825/2893 ORAS5_1979_06_net_downward_heat_flux_boxed.nc
# [u_current] 850/2893 ORAS5_1979_12_thetao_potential_temperature_boxed.nc
# [u_current] 875/2893 ORAS5_1980_06_u_rotated_boxed.nc
# [u_current] 900/2893 ORAS5_1980_12_u_zonal_boxed.nc
# [u_current] 925/2893 ORAS5_1981_07_net_downward_heat_flux_boxed.nc
# [u_current] 950/2893 ORAS5_1982_01_thetao_potential_temperature_boxed.nc
# [u_current] 975/2893 ORAS5_1982_07_u_rotated_boxed.nc
# [u_current] 1000/2893 ORAS5_1983_01_u_zonal_boxed.nc
# [u_current] 1025/2893 ORAS5_1983_08_net_downward_heat_flux_boxed.nc
# [u_current] 1050/2893 ORAS5_1984_02_thetao_potential_temperature_boxed.nc
# [u_current] 1075/2893 ORAS5_1984_08_u_rotated_boxed.nc
# [u_current] 1100/2893 ORAS5_1985_02_u_zonal_boxed.nc
# [u_current] 1125/2893 ORAS5_1985_09_net_downward_heat_flux_boxed.nc
# [u_current] 1150/2893 ORAS5_1986_03_thetao_potential_temperature_boxed.nc
# [u_current] 1175/2893 ORAS5_1986_09_u_rotated_boxed.nc
# [u_current] 1200/2893 ORAS5_1987_03_u_zonal_boxed.nc
# [u_current] 1225/2893 ORAS5_1987_10_net_downward_heat_flux_boxed.nc
# [u_current] 1250/2893 ORAS5_1988_04_thetao_potential_temperature_boxed.nc
# [u_current] 1275/2893 ORAS5_1988_10_u_rotated_boxed.nc
# [u_current] 1300/2893 ORAS5_1989_04_u_zonal_boxed.nc
# [u_current] 1325/2893 ORAS5_1989_11_net_downward_heat_flux_boxed.nc
# [u_current] 1350/2893 ORAS5_1990_05_thetao_potential_temperature_boxed.nc
# [u_current] 1375/2893 ORAS5_1990_11_u_rotated_boxed.nc
# [u_current] 1400/2893 ORAS5_1991_05_u_zonal_boxed.nc
# [u_current] 1425/2893 ORAS5_1991_12_net_downward_heat_flux_boxed.nc
# [u_current] 1450/2893 ORAS5_1992_06_thetao_potential_temperature_boxed.nc
# [u_current] 1475/2893 ORAS5_1992_12_u_rotated_boxed.nc
# [u_current] 1500/2893 ORAS5_1993_06_u_zonal_boxed.nc
# [u_current] 1525/2893 ORAS5_1994_01_net_downward_heat_flux_boxed.nc
# [u_current] 1550/2893 ORAS5_1994_07_thetao_potential_temperature_boxed.nc
# [u_current] 1575/2893 ORAS5_1995_01_u_rotated_boxed.nc
# [u_current] 1600/2893 ORAS5_1995_07_u_zonal_boxed.nc
# [u_current] 1625/2893 ORAS5_1996_02_net_downward_heat_flux_boxed.nc
# [u_current] 1650/2893 ORAS5_1996_08_thetao_potential_temperature_boxed.nc
# [u_current] 1675/2893 ORAS5_1997_02_u_rotated_boxed.nc
# [u_current] 1700/2893 ORAS5_1997_08_u_zonal_boxed.nc
# [u_current] 1725/2893 ORAS5_1998_03_net_downward_heat_flux_boxed.nc
# [u_current] 1750/2893 ORAS5_1998_09_thetao_potential_temperature_boxed.nc
# [u_current] 1775/2893 ORAS5_1999_03_u_rotated_boxed.nc
# [u_current] 1800/2893 ORAS5_1999_09_u_zonal_boxed.nc
# [u_current] 1825/2893 ORAS5_2000_04_net_downward_heat_flux_boxed.nc
# [u_current] 1850/2893 ORAS5_2000_10_thetao_potential_temperature_boxed.nc
# [u_current] 1875/2893 ORAS5_2001_04_u_rotated_boxed.nc
# [u_current] 1900/2893 ORAS5_2001_10_u_zonal_boxed.nc
# [u_current] 1925/2893 ORAS5_2002_05_net_downward_heat_flux_boxed.nc
# [u_current] 1950/2893 ORAS5_2002_11_thetao_potential_temperature_boxed.nc
# [u_current] 1975/2893 ORAS5_2003_05_u_rotated_boxed.nc
# [u_current] 2000/2893 ORAS5_2003_11_u_zonal_boxed.nc
# [u_current] 2025/2893 ORAS5_2004_06_net_downward_heat_flux_boxed.nc
# [u_current] 2050/2893 ORAS5_2004_12_thetao_potential_temperature_boxed.nc
# [u_current] 2075/2893 ORAS5_2005_06_u_rotated_boxed.nc
# [u_current] 2100/2893 ORAS5_2005_12_u_zonal_boxed.nc
# [u_current] 2125/2893 ORAS5_2006_07_net_downward_heat_flux_boxed.nc
# [u_current] 2150/2893 ORAS5_2007_01_thetao_potential_temperature_boxed.nc
# [u_current] 2175/2893 ORAS5_2007_07_u_rotated_boxed.nc
# [u_current] 2200/2893 ORAS5_2008_01_u_zonal_boxed.nc
# [u_current] 2225/2893 ORAS5_2008_08_net_downward_heat_flux_boxed.nc
# [u_current] 2250/2893 ORAS5_2009_02_thetao_potential_temperature_boxed.nc
# [u_current] 2275/2893 ORAS5_2009_08_u_rotated_boxed.nc
# [u_current] 2300/2893 ORAS5_2010_02_u_zonal_boxed.nc
# [u_current] 2325/2893 ORAS5_2010_09_net_downward_heat_flux_boxed.nc
# [u_current] 2350/2893 ORAS5_2011_03_thetao_potential_temperature_boxed.nc
# [u_current] 2375/2893 ORAS5_2011_09_u_rotated_boxed.nc
# [u_current] 2400/2893 ORAS5_2012_03_u_zonal_boxed.nc
# [u_current] 2425/2893 ORAS5_2012_10_net_downward_heat_flux_boxed.nc
# [u_current] 2450/2893 ORAS5_2013_04_thetao_potential_temperature_boxed.nc
# [u_current] 2475/2893 ORAS5_2013_10_u_rotated_boxed.nc
# [u_current] 2500/2893 ORAS5_2014_04_u_zonal_boxed.nc
# [u_current] 2525/2893 ORAS5_2014_11_net_downward_heat_flux_boxed.nc
# [u_current] 2550/2893 ORAS5_2015_05_thetao_potential_temperature_boxed.nc
# [u_current] 2575/2893 ORAS5_2015_11_u_rotated_boxed.nc
# [u_current] 2600/2893 ORAS5_2016_05_u_zonal_boxed.nc
# [u_current] 2625/2893 ORAS5_2016_12_net_downward_heat_flux_boxed.nc
# [u_current] 2650/2893 ORAS5_2017_06_thetao_potential_temperature_boxed.nc
# [u_current] 2675/2893 ORAS5_2017_12_u_rotated_boxed.nc
# [u_current] 2700/2893 ORAS5_2018_06_u_zonal_boxed.nc
# [u_current] 2725/2893 ORAS5_2019_01_net_downward_heat_flux_boxed.nc
# [u_current] 2750/2893 ORAS5_2019_07_thetao_potential_temperature_boxed.nc
# [u_current] 2775/2893 ORAS5_2020_01_u_rotated_boxed.nc
# [u_current] 2800/2893 ORAS5_2020_07_u_zonal_boxed.nc
# [u_current] 2825/2893 ORAS5_2021_02_net_downward_heat_flux_boxed.nc
# [u_current] 2850/2893 ORAS5_2024_12_thetao_potential_temperature_boxed.nc
# [u_current] 2875/2893 ORAS5_2025_06_u_zonal_boxed.nc
# [u_current] 2893/2893 ORAS5_2025_12_u_zonal_boxed.nc
# u_current_DJF (66, 99, 80) ('year', 'y', 'x')
# u_current_MAM (65, 99, 80) ('year', 'y', 'x')
# u_current_JJA (65, 99, 80) ('year', 'y', 'x')
# u_current_SON (65, 99, 80) ('year', 'y', 'x')

# %% [markdown]
# ## Combining the Variables
#
# The seasonal fields are combined into a single xarray dataset containing all features on the same grid.
#
# Unlike the earlier annual version, the dataset now contains seasonal versions of each variable, such as:
# - sst_DJF
# - sst_MAM
# - sst_JJA
# - sst_SON
#
# This dataset can also be saved so that the expensive preprocessing step does not need to be repeated.

# %%
ds_features = xr.Dataset(seasonal_fields)
print(ds_features)

feature_nc = OUT_DIR / "seasonal_feature_fields.nc"
ds_features.to_netcdf(feature_nc)
# Out:
# <xarray.Dataset> Size: 52MB
# Dimensions:        (year: 69, y: 99, x: 80)
# Coordinates:
#   * year           (year) int32 276B 1958 1959 1960 1961 ... 2023 2024 2025 2026
#   * y              (y) int32 396B 0 1 2 3 4 5 6 7 8 ... 91 92 93 94 95 96 97 98
#   * x              (x) int32 320B 0 1 2 3 4 5 6 7 8 ... 72 73 74 75 76 77 78 79
# Data variables: (12/24)
#     v_current_DJF  (year, y, x) float32 2MB 0.00679 -0.003478 ... -9.223e+18
#     v_current_MAM  (year, y, x) float32 2MB -0.0194 -0.02344 ... nan nan
#     v_current_JJA  (year, y, x) float32 2MB 0.01982 0.0206 0.0186 ... nan nan
#     v_current_SON  (year, y, x) float32 2MB 0.02468 0.02238 0.01165 ... nan nan
#     sst_DJF        (year, y, x) float32 2MB 23.08 23.04 22.97 ... nan nan nan
#     sst_MAM        (year, y, x) float32 2MB 23.34 23.3 23.27 ... nan nan nan
#     ...             ...
#     qnet_JJA       (year, y, x) float32 2MB 84.41 83.02 83.1 ... nan nan nan
#     qnet_SON       (year, y, x) float32 2MB -47.03 -46.16 -44.57 ... nan nan nan
#     u_current_DJF  (year, y, x) float32 2MB -28.94 -27.8 ... -9.223e+18
#     u_current_MAM  (year, y, x) float32 2MB 26.97 27.48 27.94 ... nan nan nan
#     u_current_JJA  (year, y, x) float32 2MB 36.57 36.11 36.13 ... nan nan nan
#     u_current_SON  (year, y, x) float32 2MB -6.921 -6.633 -6.113 ... nan nan nan

# %% [markdown]
# ## Building the Feature Table
#
# Convert the gridded seasonal dataset into a table that can be used by scikit-learn.
#
# In this format:
# Rows = grid cell in a particular year
# Columns = seasonal feature values for that cell and year
#
# This means that each original variable is now split into four separate predictors, one for each season.
#
# For example:
# - sst_DJF
# - sst_MAM
# - sst_JJA
# - sst_SON

# %%
spatial_dims = [d for d in ds_features[list(ds_features.data_vars)[0]].dims if d != "year"]
print("Spatial dims:", spatial_dims)

tmp = ds_features.reset_coords(drop=True)
stacked = tmp.stack(cell=spatial_dims)

df = pd.DataFrame({
    "year": stacked["year"].values.repeat(stacked.sizes["cell"]),
    "cell": np.tile(np.arange(stacked.sizes["cell"]), stacked.sizes["year"]),
})

for var in list(tmp.data_vars):
    df[var] = stacked[var].values.reshape(-1)

feature_cols = list(tmp.data_vars)
df = df.dropna(subset=feature_cols).reset_index(drop=True)

print(df.shape)
display(df.head())
# Out:
# Spatial dims: ['y', 'x']
# (491446, 26)
#    year  cell  v_current_DJF  v_current_MAM  v_current_JJA  v_current_SON  \
# 0  1958     0       0.006790      -0.019395       0.019824       0.024680
# 1  1958     1      -0.003478      -0.023441       0.020599       0.022384
# 2  1958     2      -0.015089      -0.023447       0.018603       0.011649
# 3  1958     3      -0.025803      -0.018765       0.013696      -0.001085
# 4  1958     4      -0.032781      -0.011291       0.008937      -0.011727
#
#      sst_DJF    sst_MAM    sst_JJA    sst_SON  ...  thetao_JJA  thetao_SON  \
# 0  23.081875  23.342749  26.684586  27.132492  ...   25.329569   26.210318
# 1  23.036140  23.302185  26.660797  27.105631  ...   25.328112   26.202696
# 2  22.965044  23.265081  26.627966  27.073080  ...   25.319811   26.181671
# 3  22.877663  23.229858  26.583008  27.036942  ...   25.296522   26.153458
# 4  22.789734  23.197882  26.531982  26.998636  ...   25.262808   26.127771
#
#      qnet_DJF   qnet_MAM   qnet_JJA   qnet_SON  u_current_DJF  u_current_MAM  \
# 0 -109.925171  57.957458  84.414146 -47.034698     -28.943819      26.973577
# 1 -106.454025  59.523342  83.020897 -46.161755     -27.802544      27.483009
# 2  -97.274475  60.918400  83.096519 -44.573589     -24.766256      27.935493
# 3  -85.749893  61.221924  84.333427 -43.689594     -20.954046      28.024498
# 4  -74.623825  60.483521  86.279884 -42.919056     -17.276106      27.768185
#
#    u_current_JJA  u_current_SON
# 0      36.572166      -6.920548
# 1      36.107403      -6.632692
# 2      36.130207      -6.113291
# 3      36.534649      -5.831792
# 4      37.171875      -5.587060
#
# [5 rows x 26 columns]

# %% [markdown]
# # Inflection = 1980 (First Third)

# %% [markdown]
# ## Defining the Target Variable
#
# I define a binary classification target based on year:
#
# - 0 = before the threshold year
# - 1 = from the threshold year onward
#
# I also print the class balance to check how evenly the two regimes are represented in the final cell-year table.

# %%
MID_YEAR = 1980
print("Inflection = ", MID_YEAR)

df["target"] = (df["year"] >= MID_YEAR).astype(int)

keep_cols = ["year", "cell"] + feature_cols + ["target"]
for c in df.columns:
    if c in keep_cols:
        continue
    # keep coordinate columns if useful
    if c.lower() in ["lat", "lon", "latitude", "longitude", "nav_lat", "nav_lon", "x", "y"]:
        keep_cols.append(c)

df = df[keep_cols]

print("Class balance:")
print(df["target"].value_counts())
display(df.head())
# Out:
# Inflection =  1980
# Class balance:
# target
# 1    319841
# 0    171605
# Name: count, dtype: int64
#    year  cell  v_current_DJF  v_current_MAM  v_current_JJA  v_current_SON  \
# 0  1958     0       0.006790      -0.019395       0.019824       0.024680
# 1  1958     1      -0.003478      -0.023441       0.020599       0.022384
# 2  1958     2      -0.015089      -0.023447       0.018603       0.011649
# 3  1958     3      -0.025803      -0.018765       0.013696      -0.001085
# 4  1958     4      -0.032781      -0.011291       0.008937      -0.011727
#
#      sst_DJF    sst_MAM    sst_JJA    sst_SON  ...  thetao_SON    qnet_DJF  \
# 0  23.081875  23.342749  26.684586  27.132492  ...   26.210318 -109.925171
# 1  23.036140  23.302185  26.660797  27.105631  ...   26.202696 -106.454025
# 2  22.965044  23.265081  26.627966  27.073080  ...   26.181671  -97.274475
# 3  22.877663  23.229858  26.583008  27.036942  ...   26.153458  -85.749893
# 4  22.789734  23.197882  26.531982  26.998636  ...   26.127771  -74.623825
#
#     qnet_MAM   qnet_JJA   qnet_SON  u_current_DJF  u_current_MAM  \
# 0  57.957458  84.414146 -47.034698     -28.943819      26.973577
# 1  59.523342  83.020897 -46.161755     -27.802544      27.483009
# 2  60.918400  83.096519 -44.573589     -24.766256      27.935493
# 3  61.221924  84.333427 -43.689594     -20.954046      28.024498
# 4  60.483521  86.279884 -42.919056     -17.276106      27.768185
#
#    u_current_JJA  u_current_SON  target
# 0      36.572166      -6.920548       0
# 1      36.107403      -6.632692       0
# 2      36.130207      -6.113291       0
# 3      36.534649      -5.831792       0
# 4      37.171875      -5.587060       0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Train / Test Split
#
# Split the dataset into training and testing sets.
#
# A stratified split is used so that the class proportions remain roughly the same in both sets.

# %%
model_features = feature_cols

X = df[model_features].copy()
y = df["target"].copy()

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=1,
    stratify=y
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
print("Train balance:", y_train.value_counts().to_dict())
print("Test balance:", y_test.value_counts().to_dict())
# Out:
# Train shape: (393156, 24)
# Test shape: (98290, 24)
# Train balance: {1: 255872, 0: 137284}
# Test balance: {1: 63969, 0: 34321}

# %% [markdown]
# ## Training the Model
#
# Train a histogram gradient boosting classifier using the annual features.
#
# Boosted tree models are well suited to large tabular datasets and can capture nonlinear relationships between variables.

# %%
model = HistGradientBoostingClassifier(
    max_depth=6,
    learning_rate=0.05,
    max_iter=200,
    random_state=1
)

model.fit(X_train, y_train)
print("Model trained.")
# Out:
# Model trained.

# %% [markdown]
# ## Model Evaluation
#
# Evaluate the classifier using:
# - the classification report
# - the confusion matrix
# - the ROC curve and AUC score
#
# Here I plot both the training and testing ROC curves on the same figure.
#
# This makes it easier to compare how well the model fits the training data and how well it generalises to unseen data.
# A large gap between the two curves suggest overfitting, similar curves suggest that the model is generalising well.

# %%
from sklearn.metrics import roc_curve, auc

pred_test = model.predict(X_test)
proba_test = model.predict_proba(X_test)[:, 1]

pred_train = model.predict(X_train)
proba_train = model.predict_proba(X_train)[:, 1]

print("TEST PERFORMANCE")
print(classification_report(y_test, pred_test, zero_division=0))
print("Confusion matrix:\n", confusion_matrix(y_test, pred_test))

fpr_test, tpr_test, _ = roc_curve(y_test, proba_test)
auc_test = auc(fpr_test, tpr_test)

fpr_train, tpr_train, _ = roc_curve(y_train, proba_train)
auc_train = auc(fpr_train, tpr_train)

fig = plt.figure(figsize=(6,5))

plt.plot(fpr_train, tpr_train, label=f"Train AUC = {auc_train:.3f}")
plt.plot(fpr_test, tpr_test, label=f"Test AUC = {auc_test:.3f}")

plt.plot([0,1], [0,1], '--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Train vs Test)")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# TEST PERFORMANCE
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92     34321
#            1       0.93      0.99      0.96     63969
#
#     accuracy                           0.95     98290
#    macro avg       0.96      0.93      0.94     98290
# weighted avg       0.95      0.95      0.95     98290
#
# Confusion matrix:
#  [[29801  4520]
#  [  560 63409]]

# %% [markdown]
# Using annual means, the area under the testing curve was 0.897 as opposed to 0.949 using seasonal means.

# %% [markdown]
# ## Output Distributions
#
# Plot the distribution of the model output probabilities for both classes.
#
# This gives a direct view of how confidently the classifier separates the two regimes.
# Separate panels are shown for the training and testing data so that the model behaviour can be compared between the two.

# %%
proba_train = model.predict_proba(X_train)[:, 1]
proba_test  = model.predict_proba(X_test)[:, 1]

fig, axes = plt.subplots(1, 2, figsize=(10,4), sharey=True)

axes[0].hist(
    proba_train[y_train == 0],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 0"
)
axes[0].hist(
    proba_train[y_train == 1],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 1"
)
axes[0].set_title("Train Output Distribution")
axes[0].set_xlabel("Predicted probability (class 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[1].hist(
    proba_test[y_test == 0],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 0"
)
axes[1].hist(
    proba_test[y_test == 1],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 1"
)
axes[1].set_title("Test Output Distribution")
axes[1].set_xlabel("Predicted probability (class 1)")
axes[1].legend()

plt.suptitle("Model Output Distributions (Confidence Separation)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Importance
#
# Permutation importance is used to see which variables and seasons the model relies on most strongly.
#
# Each feature is shuffled and the drop in model performance is measured.
#
# Because each original variable is now split by season, this allows me to see not only which physical variables matter most, but also which seasons contain the strongest signal.

# %%
perm = permutation_importance(
    model, X_test, y_test,
    n_repeats=5,
    random_state=1,
    scoring="roc_auc"
)

imp_df = pd.DataFrame({
    "feature": model_features,
    "importance_mean": perm.importances_mean,
    "importance_std": perm.importances_std
}).sort_values("importance_mean", ascending=True)

display(imp_df.sort_values("importance_mean", ascending=False))

# %% [markdown]
# ## Visualising Feature Importance
#
# Plot the permutation importances as a bar chart to show which variables contribute most to the classification.

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.barh(imp_df["feature"], imp_df["importance_mean"], xerr=imp_df["importance_std"])
ax.set_xlabel("Permutation importance (AUC drop)")
ax.set_title("Feature importance")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Matrix
#
# Calculate the Pearson correlation matrix between the seasonal input variables.
#
# This helps identify whether some predictors contain similar information:
# - across different physical variables
# - across different seasons of the same variable
#
# This is useful for checking redundancy in the expanded 24-feature dataset.

# %%
corr = X.corr().round(2)

fig = plt.figure(figsize=(7,6))

im = plt.imshow(corr, cmap="RdYlGn", vmin=-1, vmax=1)
plt.colorbar(im, label="Pearson r")

labels = corr.columns
plt.xticks(range(len(labels)), labels, rotation=45, ha="right")
plt.yticks(range(len(labels)), labels)

for i in range(len(corr)):
    for j in range(len(corr)):
        plt.text(j, i, corr.iloc[i, j],
                 ha="center", va="center", fontsize=8)

plt.title("Feature Correlation Matrix")
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Feature Distributions
#
# Plot histograms of each seasonal feature before and after the threshold year.
#
# This gives a simple view of how the two regimes differ in each variable and season individually.

# %%
features = feature_cols
n = len(features)

fig, axes = plt.subplots(n, 1, figsize=(6, 3*n), sharex=False)

if n == 1:
    axes = [axes]

for i, f in enumerate(features):

    axes[i].hist(
        df[df["target"] == 0][f],
        bins=40,
        alpha=0.6,
        label=f"< {MID_YEAR}",
        density=True
    )

    axes[i].hist(
        df[df["target"] == 1][f],
        bins=40,
        alpha=0.6,
        label=f"≥ {MID_YEAR}",
        density=True
    )

    axes[i].set_title(f)
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Density")
    axes[i].legend()

plt.suptitle("Feature Distributions by Climate Regime", y=1.02)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Regional Mean Trends
#
# Calculate the annual regional mean of each seasonal feature and plot them as time series.
#
# A linear trend is fitted to each variable and season, and the uncertainty on the trend is shown with a 1-sigma band.
#
# This makes it possible to compare how the long-term behaviour differs by both variable and season.

# %%
from scipy.stats import linregress
import numpy as np

annual_mean_df = ds_features.mean(dim=spatial_dims).to_dataframe().reset_index()

features_to_plot = [col for col in feature_cols if col in annual_mean_df.columns]
n = len(features_to_plot)

fig, axes = plt.subplots(n, 1, figsize=(7, 3.2*n), sharex=True)

if n == 1:
    axes = [axes]

for ax, col in zip(axes, features_to_plot):

    x = annual_mean_df["year"].values.astype(float)
    y = annual_mean_df[col].values.astype(float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    res = linregress(x, y)

    y_fit = res.intercept + res.slope * x

    residuals = y - y_fit
    npts = len(x)
    s = np.sqrt(np.sum(residuals**2) / (npts - 2))

    x_mean = np.mean(x)
    Sxx = np.sum((x - x_mean)**2)

    sigma_y = s * np.sqrt(1/npts + (x - x_mean)**2 / Sxx)

    ax.plot(x, y, label=col)
    ax.plot(x, y_fit, "--", label=f"slope = {res.slope:.3g} ± {res.stderr:.2g} /yr")

    ax.fill_between(
        x,
        y_fit - sigma_y,
        y_fit + sigma_y,
        alpha=0.25,
        label="1σ band"
    )

    ax.axvline(MID_YEAR, linestyle="--")

    ax.set_title(f"{col}  |  slope = {res.slope:.3g} ± {res.stderr:.2g} per year")
    ax.set_ylabel(col)
    ax.legend()

axes[-1].set_xlabel("Year")

plt.suptitle("Region-mean annual features with linear trends", y=1.02)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Inflection = 1991 (Middle)

# %% [markdown]
# ## Defining the Target Variable
#
# I define a binary classification target based on year:
#
# - 0 = before the threshold year
# - 1 = from the threshold year onward
#
# I also print the class balance to check how evenly the two regimes are represented in the final cell-year table.

# %%
MID_YEAR = 1991
print("Inflection = ", MID_YEAR)

df["target"] = (df["year"] >= MID_YEAR).astype(int)

keep_cols = ["year", "cell"] + feature_cols + ["target"]
for c in df.columns:
    if c in keep_cols:
        continue
    # keep coordinate columns if useful
    if c.lower() in ["lat", "lon", "latitude", "longitude", "nav_lat", "nav_lon", "x", "y"]:
        keep_cols.append(c)

df = df[keep_cols]

print("Class balance:")
print(df["target"].value_counts())
display(df.head())
# Out:
# Inflection =  1991
# Class balance:
# target
# 0    257416
# 1    234030
# Name: count, dtype: int64
#    year  cell  v_current_DJF  v_current_MAM  v_current_JJA  v_current_SON  \
# 0  1958     0       0.006790      -0.019395       0.019824       0.024680
# 1  1958     1      -0.003478      -0.023441       0.020599       0.022384
# 2  1958     2      -0.015089      -0.023447       0.018603       0.011649
# 3  1958     3      -0.025803      -0.018765       0.013696      -0.001085
# 4  1958     4      -0.032781      -0.011291       0.008937      -0.011727
#
#      sst_DJF    sst_MAM    sst_JJA    sst_SON  ...  thetao_SON    qnet_DJF  \
# 0  23.081875  23.342749  26.684586  27.132492  ...   26.210318 -109.925171
# 1  23.036140  23.302185  26.660797  27.105631  ...   26.202696 -106.454025
# 2  22.965044  23.265081  26.627966  27.073080  ...   26.181671  -97.274475
# 3  22.877663  23.229858  26.583008  27.036942  ...   26.153458  -85.749893
# 4  22.789734  23.197882  26.531982  26.998636  ...   26.127771  -74.623825
#
#     qnet_MAM   qnet_JJA   qnet_SON  u_current_DJF  u_current_MAM  \
# 0  57.957458  84.414146 -47.034698     -28.943819      26.973577
# 1  59.523342  83.020897 -46.161755     -27.802544      27.483009
# 2  60.918400  83.096519 -44.573589     -24.766256      27.935493
# 3  61.221924  84.333427 -43.689594     -20.954046      28.024498
# 4  60.483521  86.279884 -42.919056     -17.276106      27.768185
#
#    u_current_JJA  u_current_SON  target
# 0      36.572166      -6.920548       0
# 1      36.107403      -6.632692       0
# 2      36.130207      -6.113291       0
# 3      36.534649      -5.831792       0
# 4      37.171875      -5.587060       0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Train / Test Split
#
# Split the dataset into training and testing sets.
#
# A stratified split is used so that the class proportions remain roughly the same in both sets.

# %%
model_features = feature_cols

X = df[model_features].copy()
y = df["target"].copy()

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=1,
    stratify=y
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
print("Train balance:", y_train.value_counts().to_dict())
print("Test balance:", y_test.value_counts().to_dict())
# Out:
# Train shape: (393156, 24)
# Test shape: (98290, 24)
# Train balance: {0: 205932, 1: 187224}
# Test balance: {0: 51484, 1: 46806}

# %% [markdown]
# ## Training the Model
#
# Train a histogram gradient boosting classifier using the annual features.
#
# Boosted tree models are well suited to large tabular datasets and can capture nonlinear relationships between variables.

# %%
model = HistGradientBoostingClassifier(
    max_depth=6,
    learning_rate=0.05,
    max_iter=200,
    random_state=1
)

model.fit(X_train, y_train)
print("Model trained.")
# Out:
# Model trained.

# %% [markdown]
# ## Model Evaluation
#
# Evaluate the classifier using:
# - the classification report
# - the confusion matrix
# - the ROC curve and AUC score
#
# Here I plot both the training and testing ROC curves on the same figure.
#
# This makes it easier to compare how well the model fits the training data and how well it generalises to unseen data.
# A large gap between the two curves suggest overfitting, similar curves suggest that the model is generalising well.

# %%
from sklearn.metrics import roc_curve, auc

pred_test = model.predict(X_test)
proba_test = model.predict_proba(X_test)[:, 1]

pred_train = model.predict(X_train)
proba_train = model.predict_proba(X_train)[:, 1]

print("TEST PERFORMANCE")
print(classification_report(y_test, pred_test, zero_division=0))
print("Confusion matrix:\n", confusion_matrix(y_test, pred_test))

fpr_test, tpr_test, _ = roc_curve(y_test, proba_test)
auc_test = auc(fpr_test, tpr_test)

fpr_train, tpr_train, _ = roc_curve(y_train, proba_train)
auc_train = auc(fpr_train, tpr_train)

fig = plt.figure(figsize=(6,5))

plt.plot(fpr_train, tpr_train, label=f"Train AUC = {auc_train:.3f}")
plt.plot(fpr_test, tpr_test, label=f"Test AUC = {auc_test:.3f}")

plt.plot([0,1], [0,1], '--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Train vs Test)")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# TEST PERFORMANCE
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86     51484
#            1       0.83      0.88      0.86     46806
#
#     accuracy                           0.86     98290
#    macro avg       0.86      0.86      0.86     98290
# weighted avg       0.86      0.86      0.86     98290
#
# Confusion matrix:
#  [[43212  8272]
#  [ 5614 41192]]

# %% [markdown]
# Using annual means, the area under the testing curve was 0.897 as opposed to 0.949 using seasonal means.

# %% [markdown]
# ## Output Distributions
#
# Plot the distribution of the model output probabilities for both classes.
#
# This gives a direct view of how confidently the classifier separates the two regimes.
# Separate panels are shown for the training and testing data so that the model behaviour can be compared between the two.

# %%
proba_train = model.predict_proba(X_train)[:, 1]
proba_test  = model.predict_proba(X_test)[:, 1]

fig, axes = plt.subplots(1, 2, figsize=(10,4), sharey=True)

axes[0].hist(
    proba_train[y_train == 0],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 0"
)
axes[0].hist(
    proba_train[y_train == 1],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 1"
)
axes[0].set_title("Train Output Distribution")
axes[0].set_xlabel("Predicted probability (class 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[1].hist(
    proba_test[y_test == 0],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 0"
)
axes[1].hist(
    proba_test[y_test == 1],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 1"
)
axes[1].set_title("Test Output Distribution")
axes[1].set_xlabel("Predicted probability (class 1)")
axes[1].legend()

plt.suptitle("Model Output Distributions (Confidence Separation)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Importance
#
# Permutation importance is used to see which variables and seasons the model relies on most strongly.
#
# Each feature is shuffled and the drop in model performance is measured.
#
# Because each original variable is now split by season, this allows me to see not only which physical variables matter most, but also which seasons contain the strongest signal.

# %%
perm = permutation_importance(
    model, X_test, y_test,
    n_repeats=5,
    random_state=1,
    scoring="roc_auc"
)

imp_df = pd.DataFrame({
    "feature": model_features,
    "importance_mean": perm.importances_mean,
    "importance_std": perm.importances_std
}).sort_values("importance_mean", ascending=True)

display(imp_df.sort_values("importance_mean", ascending=False))
# Out:
#           feature  importance_mean  importance_std
# 22  u_current_JJA         0.235662        0.001650
# 18       qnet_JJA         0.208445        0.000525
# 15     thetao_SON         0.060022        0.000577
# 6         sst_JJA         0.047352        0.000398
# 21  u_current_MAM         0.034077        0.000140
# 14     thetao_JJA         0.025837        0.000342
# 8    salinity_DJF         0.021310        0.000407
# 16       qnet_DJF         0.018353        0.000224
# 12     thetao_DJF         0.018119        0.000433
# 13     thetao_MAM         0.015966        0.000347
# 11   salinity_SON         0.012824        0.000345
# 10   salinity_JJA         0.012569        0.000252
# 23  u_current_SON         0.010579        0.000176
# 4         sst_DJF         0.009556        0.000096
# 20  u_current_DJF         0.009387        0.000124
# 19       qnet_SON         0.007819        0.000054
# 17       qnet_MAM         0.007515        0.000046
# 9    salinity_MAM         0.007251        0.000096
# 7         sst_SON         0.007183        0.000207
# 2   v_current_JJA         0.006374        0.000113
# 3   v_current_SON         0.003204        0.000107
# 5         sst_MAM         0.002732        0.000026
# 1   v_current_MAM         0.002135        0.000088
# 0   v_current_DJF         0.000319        0.000012

# %% [markdown]
# ## Visualising Feature Importance
#
# Plot the permutation importances as a bar chart to show which variables contribute most to the classification.

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.barh(imp_df["feature"], imp_df["importance_mean"], xerr=imp_df["importance_std"])
ax.set_xlabel("Permutation importance (AUC drop)")
ax.set_title("Feature importance")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Matrix
#
# Calculate the Pearson correlation matrix between the seasonal input variables.
#
# This helps identify whether some predictors contain similar information:
# - across different physical variables
# - across different seasons of the same variable
#
# This is useful for checking redundancy in the expanded 24-feature dataset.

# %%
corr = X.corr().round(2)

fig = plt.figure(figsize=(7,6))

im = plt.imshow(corr, cmap="RdYlGn", vmin=-1, vmax=1)
plt.colorbar(im, label="Pearson r")

labels = corr.columns
plt.xticks(range(len(labels)), labels, rotation=45, ha="right")
plt.yticks(range(len(labels)), labels)

for i in range(len(corr)):
    for j in range(len(corr)):
        plt.text(j, i, corr.iloc[i, j],
                 ha="center", va="center", fontsize=8)

plt.title("Feature Correlation Matrix")
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Feature Distributions
#
# Plot histograms of each seasonal feature before and after the threshold year.
#
# This gives a simple view of how the two regimes differ in each variable and season individually.

# %%
features = feature_cols
n = len(features)

fig, axes = plt.subplots(n, 1, figsize=(6, 3*n), sharex=False)

if n == 1:
    axes = [axes]

for i, f in enumerate(features):

    axes[i].hist(
        df[df["target"] == 0][f],
        bins=40,
        alpha=0.6,
        label=f"< {MID_YEAR}",
        density=True
    )

    axes[i].hist(
        df[df["target"] == 1][f],
        bins=40,
        alpha=0.6,
        label=f"≥ {MID_YEAR}",
        density=True
    )

    axes[i].set_title(f)
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Density")
    axes[i].legend()

plt.suptitle("Feature Distributions by Climate Regime", y=1.02)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Regional Mean Trends
#
# Calculate the annual regional mean of each seasonal feature and plot them as time series.
#
# A linear trend is fitted to each variable and season, and the uncertainty on the trend is shown with a 1-sigma band.
#
# This makes it possible to compare how the long-term behaviour differs by both variable and season.

# %%
from scipy.stats import linregress
import numpy as np

annual_mean_df = ds_features.mean(dim=spatial_dims).to_dataframe().reset_index()

features_to_plot = [col for col in feature_cols if col in annual_mean_df.columns]
n = len(features_to_plot)

fig, axes = plt.subplots(n, 1, figsize=(7, 3.2*n), sharex=True)

if n == 1:
    axes = [axes]

for ax, col in zip(axes, features_to_plot):

    x = annual_mean_df["year"].values.astype(float)
    y = annual_mean_df[col].values.astype(float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    res = linregress(x, y)

    y_fit = res.intercept + res.slope * x

    residuals = y - y_fit
    npts = len(x)
    s = np.sqrt(np.sum(residuals**2) / (npts - 2))

    x_mean = np.mean(x)
    Sxx = np.sum((x - x_mean)**2)

    sigma_y = s * np.sqrt(1/npts + (x - x_mean)**2 / Sxx)

    ax.plot(x, y, label=col)
    ax.plot(x, y_fit, "--", label=f"slope = {res.slope:.3g} ± {res.stderr:.2g} /yr")

    ax.fill_between(
        x,
        y_fit - sigma_y,
        y_fit + sigma_y,
        alpha=0.25,
        label="1σ band"
    )

    ax.axvline(MID_YEAR, linestyle="--")

    ax.set_title(f"{col}  |  slope = {res.slope:.3g} ± {res.stderr:.2g} per year")
    ax.set_ylabel(col)
    ax.legend()

axes[-1].set_xlabel("Year")

plt.suptitle("Region-mean annual features with linear trends", y=1.02)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Inflection = 2003 (Final Third)

# %% [markdown]
# ## Defining the Target Variable
#
# I define a binary classification target based on year:
#
# - 0 = before the threshold year
# - 1 = from the threshold year onward
#
# I also print the class balance to check how evenly the two regimes are represented in the final cell-year table.

# %%
MID_YEAR = 2003
print("Inflection = ", MID_YEAR)

df["target"] = (df["year"] >= MID_YEAR).astype(int)

keep_cols = ["year", "cell"] + feature_cols + ["target"]
for c in df.columns:
    if c in keep_cols:
        continue
    # keep coordinate columns if useful
    if c.lower() in ["lat", "lon", "latitude", "longitude", "nav_lat", "nav_lon", "x", "y"]:
        keep_cols.append(c)

df = df[keep_cols]

print("Class balance:")
print(df["target"].value_counts())
display(df.head())
# Out:
# Inflection =  2003
# Class balance:
# target
# 0    351028
# 1    140418
# Name: count, dtype: int64
#    year  cell  v_current_DJF  v_current_MAM  v_current_JJA  v_current_SON  \
# 0  1958     0       0.006790      -0.019395       0.019824       0.024680
# 1  1958     1      -0.003478      -0.023441       0.020599       0.022384
# 2  1958     2      -0.015089      -0.023447       0.018603       0.011649
# 3  1958     3      -0.025803      -0.018765       0.013696      -0.001085
# 4  1958     4      -0.032781      -0.011291       0.008937      -0.011727
#
#      sst_DJF    sst_MAM    sst_JJA    sst_SON  ...  thetao_SON    qnet_DJF  \
# 0  23.081875  23.342749  26.684586  27.132492  ...   26.210318 -109.925171
# 1  23.036140  23.302185  26.660797  27.105631  ...   26.202696 -106.454025
# 2  22.965044  23.265081  26.627966  27.073080  ...   26.181671  -97.274475
# 3  22.877663  23.229858  26.583008  27.036942  ...   26.153458  -85.749893
# 4  22.789734  23.197882  26.531982  26.998636  ...   26.127771  -74.623825
#
#     qnet_MAM   qnet_JJA   qnet_SON  u_current_DJF  u_current_MAM  \
# 0  57.957458  84.414146 -47.034698     -28.943819      26.973577
# 1  59.523342  83.020897 -46.161755     -27.802544      27.483009
# 2  60.918400  83.096519 -44.573589     -24.766256      27.935493
# 3  61.221924  84.333427 -43.689594     -20.954046      28.024498
# 4  60.483521  86.279884 -42.919056     -17.276106      27.768185
#
#    u_current_JJA  u_current_SON  target
# 0      36.572166      -6.920548       0
# 1      36.107403      -6.632692       0
# 2      36.130207      -6.113291       0
# 3      36.534649      -5.831792       0
# 4      37.171875      -5.587060       0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Train / Test Split
#
# Split the dataset into training and testing sets.
#
# A stratified split is used so that the class proportions remain roughly the same in both sets.

# %%
model_features = feature_cols

X = df[model_features].copy()
y = df["target"].copy()

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=1,
    stratify=y
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
print("Train balance:", y_train.value_counts().to_dict())
print("Test balance:", y_test.value_counts().to_dict())
# Out:
# Train shape: (393156, 24)
# Test shape: (98290, 24)
# Train balance: {0: 280822, 1: 112334}
# Test balance: {0: 70206, 1: 28084}

# %% [markdown]
# ## Training the Model
#
# Train a histogram gradient boosting classifier using the annual features.
#
# Boosted tree models are well suited to large tabular datasets and can capture nonlinear relationships between variables.

# %%
model = HistGradientBoostingClassifier(
    max_depth=6,
    learning_rate=0.05,
    max_iter=200,
    random_state=1
)

model.fit(X_train, y_train)
print("Model trained.")
# Out:
# Model trained.

# %% [markdown]
# ## Model Evaluation
#
# Evaluate the classifier using:
# - the classification report
# - the confusion matrix
# - the ROC curve and AUC score
#
# Here I plot both the training and testing ROC curves on the same figure.
#
# This makes it easier to compare how well the model fits the training data and how well it generalises to unseen data.
# A large gap between the two curves suggest overfitting, similar curves suggest that the model is generalising well.

# %%
from sklearn.metrics import roc_curve, auc

pred_test = model.predict(X_test)
proba_test = model.predict_proba(X_test)[:, 1]

pred_train = model.predict(X_train)
proba_train = model.predict_proba(X_train)[:, 1]

print("TEST PERFORMANCE")
print(classification_report(y_test, pred_test, zero_division=0))
print("Confusion matrix:\n", confusion_matrix(y_test, pred_test))

fpr_test, tpr_test, _ = roc_curve(y_test, proba_test)
auc_test = auc(fpr_test, tpr_test)

fpr_train, tpr_train, _ = roc_curve(y_train, proba_train)
auc_train = auc(fpr_train, tpr_train)

fig = plt.figure(figsize=(6,5))

plt.plot(fpr_train, tpr_train, label=f"Train AUC = {auc_train:.3f}")
plt.plot(fpr_test, tpr_test, label=f"Test AUC = {auc_test:.3f}")

plt.plot([0,1], [0,1], '--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Train vs Test)")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# TEST PERFORMANCE
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90     70206
#            1       0.85      0.59      0.70     28084
#
#     accuracy                           0.85     98290
#    macro avg       0.85      0.77      0.80     98290
# weighted avg       0.85      0.85      0.84     98290
#
# Confusion matrix:
#  [[67383  2823]
#  [11550 16534]]

# %% [markdown]
# Using annual means, the area under the testing curve was 0.897 as opposed to 0.949 using seasonal means.

# %% [markdown]
# ## Output Distributions
#
# Plot the distribution of the model output probabilities for both classes.
#
# This gives a direct view of how confidently the classifier separates the two regimes.
# Separate panels are shown for the training and testing data so that the model behaviour can be compared between the two.

# %%
proba_train = model.predict_proba(X_train)[:, 1]
proba_test  = model.predict_proba(X_test)[:, 1]

fig, axes = plt.subplots(1, 2, figsize=(10,4), sharey=True)

axes[0].hist(
    proba_train[y_train == 0],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 0"
)
axes[0].hist(
    proba_train[y_train == 1],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 1"
)
axes[0].set_title("Train Output Distribution")
axes[0].set_xlabel("Predicted probability (class 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[1].hist(
    proba_test[y_test == 0],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 0"
)
axes[1].hist(
    proba_test[y_test == 1],
    bins=50,
    alpha=0.6,
    density=True,
    label="Class 1"
)
axes[1].set_title("Test Output Distribution")
axes[1].set_xlabel("Predicted probability (class 1)")
axes[1].legend()

plt.suptitle("Model Output Distributions (Confidence Separation)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Importance
#
# Permutation importance is used to see which variables and seasons the model relies on most strongly.
#
# Each feature is shuffled and the drop in model performance is measured.
#
# Because each original variable is now split by season, this allows me to see not only which physical variables matter most, but also which seasons contain the strongest signal.

# %%
perm = permutation_importance(
    model, X_test, y_test,
    n_repeats=5,
    random_state=1,
    scoring="roc_auc"
)

imp_df = pd.DataFrame({
    "feature": model_features,
    "importance_mean": perm.importances_mean,
    "importance_std": perm.importances_std
}).sort_values("importance_mean", ascending=True)

display(imp_df.sort_values("importance_mean", ascending=False))
# Out:
#           feature  importance_mean  importance_std
# 22  u_current_JJA         0.164812        0.001443
# 18       qnet_JJA         0.130085        0.000919
# 21  u_current_MAM         0.106533        0.000839
# 9    salinity_MAM         0.065568        0.000823
# 12     thetao_DJF         0.052847        0.000679
# 15     thetao_SON         0.039978        0.000815
# 14     thetao_JJA         0.036317        0.000881
# 23  u_current_SON         0.030651        0.000579
# 8    salinity_DJF         0.028108        0.000394
# 10   salinity_JJA         0.027474        0.000309
# 17       qnet_MAM         0.020194        0.000217
# 13     thetao_MAM         0.018654        0.000307
# 7         sst_SON         0.017916        0.000431
# 11   salinity_SON         0.016990        0.000375
# 20  u_current_DJF         0.013636        0.000199
# 6         sst_JJA         0.012651        0.000266
# 4         sst_DJF         0.011465        0.000205
# 16       qnet_DJF         0.009634        0.000172
# 3   v_current_SON         0.008664        0.000113
# 19       qnet_SON         0.008213        0.000180
# 2   v_current_JJA         0.006139        0.000056
# 5         sst_MAM         0.002841        0.000063
# 0   v_current_DJF         0.002755        0.000089
# 1   v_current_MAM         0.001357        0.000045

# %% [markdown]
# ## Visualising Feature Importance
#
# Plot the permutation importances as a bar chart to show which variables contribute most to the classification.

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.barh(imp_df["feature"], imp_df["importance_mean"], xerr=imp_df["importance_std"])
ax.set_xlabel("Permutation importance (AUC drop)")
ax.set_title("Feature importance")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation Matrix
#
# Calculate the Pearson correlation matrix between the seasonal input variables.
#
# This helps identify whether some predictors contain similar information:
# - across different physical variables
# - across different seasons of the same variable
#
# This is useful for checking redundancy in the expanded 24-feature dataset.

# %%
corr = X.corr().round(2)

fig = plt.figure(figsize=(7,6))

im = plt.imshow(corr, cmap="RdYlGn", vmin=-1, vmax=1)
plt.colorbar(im, label="Pearson r")

labels = corr.columns
plt.xticks(range(len(labels)), labels, rotation=45, ha="right")
plt.yticks(range(len(labels)), labels)

for i in range(len(corr)):
    for j in range(len(corr)):
        plt.text(j, i, corr.iloc[i, j],
                 ha="center", va="center", fontsize=8)

plt.title("Feature Correlation Matrix")
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Feature Distributions
#
# Plot histograms of each seasonal feature before and after the threshold year.
#
# This gives a simple view of how the two regimes differ in each variable and season individually.

# %%
features = feature_cols
n = len(features)

fig, axes = plt.subplots(n, 1, figsize=(6, 3*n), sharex=False)

if n == 1:
    axes = [axes]

for i, f in enumerate(features):

    axes[i].hist(
        df[df["target"] == 0][f],
        bins=40,
        alpha=0.6,
        label=f"< {MID_YEAR}",
        density=True
    )

    axes[i].hist(
        df[df["target"] == 1][f],
        bins=40,
        alpha=0.6,
        label=f"≥ {MID_YEAR}",
        density=True
    )

    axes[i].set_title(f)
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Density")
    axes[i].legend()

plt.suptitle("Feature Distributions by Climate Regime", y=1.02)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Regional Mean Trends
#
# Calculate the annual regional mean of each seasonal feature and plot them as time series.
#
# A linear trend is fitted to each variable and season, and the uncertainty on the trend is shown with a 1-sigma band.
#
# This makes it possible to compare how the long-term behaviour differs by both variable and season.

# %%
from scipy.stats import linregress
import numpy as np

annual_mean_df = ds_features.mean(dim=spatial_dims).to_dataframe().reset_index()

features_to_plot = [col for col in feature_cols if col in annual_mean_df.columns]
n = len(features_to_plot)

fig, axes = plt.subplots(n, 1, figsize=(7, 3.2*n), sharex=True)

if n == 1:
    axes = [axes]

for ax, col in zip(axes, features_to_plot):

    x = annual_mean_df["year"].values.astype(float)
    y = annual_mean_df[col].values.astype(float)

    mask = np.isfinite(x) & np.isfinite(y)
    x = x[mask]
    y = y[mask]

    res = linregress(x, y)

    y_fit = res.intercept + res.slope * x

    residuals = y - y_fit
    npts = len(x)
    s = np.sqrt(np.sum(residuals**2) / (npts - 2))

    x_mean = np.mean(x)
    Sxx = np.sum((x - x_mean)**2)

    sigma_y = s * np.sqrt(1/npts + (x - x_mean)**2 / Sxx)

    ax.plot(x, y, label=col)
    ax.plot(x, y_fit, "--", label=f"slope = {res.slope:.3g} ± {res.stderr:.2g} /yr")

    ax.fill_between(
        x,
        y_fit - sigma_y,
        y_fit + sigma_y,
        alpha=0.25,
        label="1σ band"
    )

    ax.axvline(MID_YEAR, linestyle="--")

    ax.set_title(f"{col}  |  slope = {res.slope:.3g} ± {res.stderr:.2g} per year")
    ax.set_ylabel(col)
    ax.legend()

axes[-1].set_xlabel("Year")

plt.suptitle("Region-mean annual features with linear trends", y=1.02)
plt.tight_layout()

plt.show()
