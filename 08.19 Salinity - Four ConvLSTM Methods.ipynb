# %% [markdown]
# # Four ConvLSTM forecasting methods (1982–2025)
#
# This notebook loads the same cached tensor once, trains two ConvLSTM models, and produces four compared forecasts:
#
# 1. **Shreya** — predicts one month at a time using the 12 *observed* preceding months.
# 2. **Adapted Shreya** — predicts one month at a time, recursively feeding its own predictions back into the next 12-month input window.
# 3. **Iarla** — predicts 12 months in one shot, using the 12 *observed* months before each calendar-year block.
# 4. **Adapted Iarla** — predicts 12 months in one shot, recursively using its previous predicted 12-month block.
#
# The forecast period is January 1982 through December 2025. The plots show the spatial box mean of `PRIMARY_FEATURE` (SST in this case), first monthly and then as annual averages. As the current tensor ends before 2025, the actual series and metrics stop at the final observed month. Observed input methods then continue recursively so that all four forecast lines still reach 2025.
#
# ## Note:
#
# - **Starting point:** both recursive methods begin with the identical observed January–December 1981 input window.
# - **Observed input methods:** Shreya uses rolling observed inputs and Iarla uses the observed previous calendar year while those observations exist. As the tensor ends before 2025, each continues recursively from that point (this is just a temporary fix).
# - **Recursive methods:** Adapted Shreya updates its window by one predicted month. Adapted Iarla replaces the entire input window with the predicted 12month block.

# %% [markdown]
# ## 1. Imports and setup

# %%
from pathlib import Path
import json
import pickle
import random
import warnings

import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Input, ConvLSTM2D, BatchNormalization, Conv2D, Reshape, Permute
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

warnings.filterwarnings("ignore", category=RuntimeWarning)
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow:", tf.__version__)
print("Available GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow: 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Available GPUs: []

# %% [markdown]
# ## 2. Configuration

# %%
CACHE_PATH = Path(
    r"C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed"
    r"\oras5_era5_monthly_25N_45N_50W_30W_0p5deg.nc"
)
OUTPUT_DIR = CACHE_PATH.parent / "ConvLSTM_four_method_1982_2025"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

LOOKBACK = 12
HORIZON = 12
VALIDATION_START = pd.Timestamp("1977-01-01")
FORECAST_START = pd.Timestamp("1982-01-01")
FORECAST_END = pd.Timestamp("2025-12-01")
PRIMARY_FEATURE = "salinity"

EPOCHS = 50
ONE_STEP_BATCH_SIZE = 4
ONE_SHOT_BATCH_SIZE = 2
LEARNING_RATE = 1e-3
TRAIN_MODELS = True

ONE_STEP_MODEL_PATH = OUTPUT_DIR / "best_one_step_convlstm.keras"
ONE_SHOT_MODEL_PATH = OUTPUT_DIR / "best_one_shot_12month_convlstm.keras"
SCALER_PATH = OUTPUT_DIR / "shared_training_only_scaler.pkl"
HISTORY_PATH = OUTPUT_DIR / "training_histories.json"
PREDICTIONS_PATH = OUTPUT_DIR / "four_method_predictions.nc"
METRICS_PATH = OUTPUT_DIR / "four_method_metrics.csv"

print("Tensor:", CACHE_PATH)
print("Outputs:", OUTPUT_DIR)
# Out:
# Tensor: C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\oras5_era5_monthly_25N_45N_50W_30W_0p5deg.nc
# Outputs: C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025

# %% [markdown]
# ## 3. Load the cached tensor

# %%
if not CACHE_PATH.exists():
    raise FileNotFoundError(f"Cached tensor not found:\n{CACHE_PATH}\nUpdate CACHE_PATH in the configuration cell.")

with xr.open_dataset(CACHE_PATH, engine="h5netcdf") as ds:
    if "climate" in ds.data_vars:
        combined_monthly = ds["climate"].load()
    elif len(ds.data_vars) == 1:
        combined_monthly = ds[next(iter(ds.data_vars))].load()
    else:
        raise ValueError(f"Could not identify tensor variable: {list(ds.data_vars)}")

combined_monthly = (
    combined_monthly.sortby("time")
    .transpose("time", "feature", "lat", "lon")
    .where(np.abs(combined_monthly) < 1e10)
    .astype(np.float32)
)

times = pd.DatetimeIndex(pd.to_datetime(combined_monthly.time.values))
candidate_features = combined_monthly.feature.values.astype(str).tolist()
train_reference_mask = times < VALIDATION_START
retained_features, quality_rows = [], []

for name in candidate_features:
    values = combined_monthly.sel(feature=name).values
    train_std = float(np.nanstd(values[train_reference_mask]))
    finite_fraction = float(np.isfinite(values).mean())
    quality_rows.append({"feature": name, "finite_fraction": finite_fraction, "training_std": train_std})
    if finite_fraction > 0 and np.isfinite(train_std) and train_std > 1e-8:
        retained_features.append(name)

display(pd.DataFrame(quality_rows))
removed = [name for name in candidate_features if name not in retained_features]
print("Removed empty/constant features:", removed)

combined_monthly = combined_monthly.sel(feature=retained_features)
features = retained_features
times = pd.DatetimeIndex(pd.to_datetime(combined_monthly.time.values))
lats, lons = combined_monthly.lat.values, combined_monthly.lon.values
raw_data = combined_monthly.transpose("time", "lat", "lon", "feature").values.astype(np.float32)

expected = pd.date_range(times.min(), times.max(), freq="MS")
missing_months = expected.difference(times)
if len(missing_months):
    print(f"Warning: tensor has {len(missing_months)} missing complete month(s):")
    print([timestamp.strftime("%Y-%m") for timestamp in missing_months])
    print("Training/validation samples crossing these gaps will be skipped.")
if PRIMARY_FEATURE not in features:
    raise ValueError(f"{PRIMARY_FEATURE!r} not found in retained features: {features}")
if times.min() > FORECAST_START - pd.DateOffset(months=LOOKBACK):
    raise ValueError("Tensor does not contain the 12 observed months needed to initialize the forecasts.")

ACTUAL_END = min(FORECAST_END, times.max())
if ACTUAL_END < FORECAST_START:
    raise ValueError("Tensor ends before the requested forecast period begins.")

required_forecast_months = pd.date_range(
    FORECAST_START - pd.DateOffset(months=LOOKBACK),
    ACTUAL_END,
    freq="MS",
)
missing_required_months = required_forecast_months.difference(times)
if len(missing_required_months):
    raise ValueError(
        "The tensor is missing month(s) required for the December 1981 initialization "
        "or observed comparison period: "
        + ", ".join(timestamp.strftime("%Y-%m") for timestamp in missing_required_months)
    )

print("Shape (time, lat, lon, feature):", raw_data.shape)
print("Features:", features)
print("Range:", times.min().strftime("%Y-%m"), "to", times.max().strftime("%Y-%m"))
print("Forecasts will run through:", FORECAST_END.strftime("%Y-%m"))
print("Actual comparison data end at:", ACTUAL_END.strftime("%Y-%m"))
if ACTUAL_END < FORECAST_END:
    print("After actual data end, observed-input methods continue recursively and the actual plot line is blank.")
# Out:
#         feature  finite_fraction  training_std
# 0           sst              1.0      4.128275
# 1      salinity              1.0      0.687953
# 2        thetao              1.0      3.708173
# 3          qnet              1.0    185.459488
# 4     u_current              1.0      0.082924
# 5     v_current              1.0      0.081375
# 6      era5_sst              1.0      4.137603
# 7      era5_u10              0.0           NaN
# 8      era5_v10              0.0           NaN
# 9   era5_runoff              1.0      0.000000
# 10     era5_d2m              0.0           NaN
# 11     era5_skt              0.0           NaN
# 12    era5_stl2              0.0           NaN
# 13   era5_swvl1              0.0           NaN
# Removed empty/constant features: ['era5_u10', 'era5_v10', 'era5_runoff', 'era5_d2m', 'era5_skt', 'era5_stl2', 'era5_swvl1']
# Warning: tensor has 1 missing complete month(s):
# ['1979-02']
# Training/validation samples crossing these gaps will be skipped.
# Shape (time, lat, lon, feature): (731, 41, 41, 7)
# Features: ['sst', 'salinity', 'thetao', 'qnet', 'u_current', 'v_current', 'era5_sst']
# Range: 1958-01 to 2018-12
# Forecasts will run through: 2025-12
# Actual comparison data end at: 2018-12
# After actual data end, observed-input methods continue recursively and the actual plot line is blank.

# %% [markdown]
# ## 4. Training set imputation/scaling

# %%
train_fit_mask = times < VALIDATION_START
n_time, n_lat, n_lon, n_features = raw_data.shape
training_reference = raw_data[train_fit_mask]
training_times = times[train_fit_mask]

month_climatology = np.full((12, n_lat, n_lon, n_features), np.nan, dtype=np.float32)
for month in range(1, 13):
    month_climatology[month - 1] = np.nanmean(training_reference[training_times.month == month], axis=0)

cell_mean = np.nanmean(training_reference, axis=0)
feature_median = np.array([np.nanmedian(training_reference[..., i]) for i in range(n_features)], dtype=np.float32)

data_filled = raw_data.copy()
for i, timestamp in enumerate(times):
    missing = ~np.isfinite(data_filled[i])
    if missing.any():
        data_filled[i][missing] = month_climatology[timestamp.month - 1][missing]
    missing = ~np.isfinite(data_filled[i])
    if missing.any():
        data_filled[i][missing] = cell_mean[missing]
    missing = ~np.isfinite(data_filled[i])
    if missing.any():
        fallback = np.broadcast_to(feature_median, data_filled[i].shape)
        data_filled[i][missing] = fallback[missing]

if not np.isfinite(data_filled).all():
    raise ValueError("Non-finite values remain after imputation.")

feature_mean = data_filled[train_fit_mask].mean(axis=(0, 1, 2)).astype(np.float32)
feature_std = data_filled[train_fit_mask].std(axis=(0, 1, 2)).astype(np.float32)
feature_std = np.where(feature_std < 1e-8, 1.0, feature_std).astype(np.float32)
data_scaled = ((data_filled - feature_mean) / feature_std).astype(np.float32)

def inverse_scale(values):
    return values * feature_std + feature_mean

with open(SCALER_PATH, "wb") as handle:
    pickle.dump({"features": features, "mean": feature_mean, "std": feature_std,
                 "month_climatology": month_climatology, "cell_mean": cell_mean,
                 "feature_median": feature_median, "fit_end": str(times[train_fit_mask][-1])}, handle)

display(pd.DataFrame({"feature": features, "training_mean": feature_mean, "training_std": feature_std}))
# Out:
#      feature  training_mean  training_std
# 0        sst      20.633944      4.128009
# 1   salinity      36.409763      0.688068
# 2     thetao      19.737841      3.707966
# 3       qnet     -28.248745    185.448532
# 4  u_current       0.023949      0.082915
# 5  v_current      -0.005960      0.081360
# 6   era5_sst      20.586727      4.137372

# %% [markdown]
# ## 5. Building one step and 12-12 training samples

# %%
def is_consecutive(months):
    months = pd.DatetimeIndex(months)
    return months.equals(pd.date_range(months[0], periods=len(months), freq="MS"))

def make_one_step_samples(values, value_times):
    X, y, targets = [], [], []
    for target_i in range(LOOKBACK, len(value_times)):
        window_times = value_times[target_i - LOOKBACK:target_i + 1]
        if is_consecutive(window_times):
            X.append(values[target_i - LOOKBACK:target_i])
            y.append(values[target_i])
            targets.append(value_times[target_i])
    return np.asarray(X, np.float32), np.asarray(y, np.float32), pd.DatetimeIndex(targets)

def make_one_shot_samples(values, value_times):
    X, y, starts, ends = [], [], [], []
    required = LOOKBACK + HORIZON
    for start_i in range(len(value_times) - required + 1):
        block_times = value_times[start_i:start_i + required]
        if is_consecutive(block_times):
            split = start_i + LOOKBACK
            X.append(values[start_i:split])
            y.append(values[split:split + HORIZON])
            starts.append(value_times[split])
            ends.append(value_times[split + HORIZON - 1])
    return (np.asarray(X, np.float32), np.asarray(y, np.float32),
            pd.DatetimeIndex(starts), pd.DatetimeIndex(ends))

X1, y1, target1 = make_one_step_samples(data_scaled, times)
train1, val1 = target1 < VALIDATION_START, (target1 >= VALIDATION_START) & (target1 < FORECAST_START)

X12, y12, start12, end12 = make_one_shot_samples(data_scaled, times)
train12 = end12 < VALIDATION_START
val12 = (start12 >= VALIDATION_START) & (end12 < FORECAST_START)

if min(train1.sum(), val1.sum(), train12.sum(), val12.sum()) == 0:
    raise ValueError("A chronological training or validation split is empty.")

print("One-step train/validation:", X1[train1].shape, X1[val1].shape)
print("One-shot train/validation:", X12[train12].shape, X12[val12].shape)
print("Training targets end before:", VALIDATION_START.date())
print("Validation targets:", VALIDATION_START.date(), "to", (FORECAST_START - pd.DateOffset(months=1)).date())
# Out:
# One-step train/validation: (216, 12, 41, 41, 7) (47, 12, 41, 41, 7)
# One-shot train/validation: (205, 12, 41, 41, 7) (25, 12, 41, 41, 7)
# Training targets end before: 1977-01-01
# Validation targets: 1977-01-01 to 1981-12-01

# %% [markdown]
# ## 6. Defining the two ConvLSTM models

# %%
def build_one_step_model():
    model = Sequential([
        Input(shape=(LOOKBACK, n_lat, n_lon, n_features)),
        ConvLSTM2D(32, (3, 3), padding="same", return_sequences=True), BatchNormalization(),
        ConvLSTM2D(32, (3, 3), padding="same", return_sequences=True), BatchNormalization(),
        ConvLSTM2D(16, (3, 3), padding="same", return_sequences=False), BatchNormalization(),
        Conv2D(n_features, (3, 3), padding="same", activation="linear"),
    ], name="Shreya_one_step_ConvLSTM")
    model.compile(optimizer=tf.keras.optimizers.Adam(LEARNING_RATE), loss="mse", metrics=["mae"])
    return model

def build_one_shot_model():
    inputs = Input(shape=(LOOKBACK, n_lat, n_lon, n_features), name="preceding_12_months")
    x = ConvLSTM2D(32, (3, 3), padding="same", return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = ConvLSTM2D(32, (3, 3), padding="same", return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = ConvLSTM2D(16, (3, 3), padding="same", return_sequences=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(HORIZON * n_features, (1, 1), padding="same", activation="linear")(x)
    x = Reshape((n_lat, n_lon, HORIZON, n_features))(x)
    outputs = Permute((3, 1, 2, 4), name="forecast_12_months")(x)
    model = Model(inputs, outputs, name="Iarla_one_shot_ConvLSTM")
    model.compile(optimizer=tf.keras.optimizers.Adam(LEARNING_RATE), loss="mse", metrics=["mae"])
    return model

one_step_model = build_one_step_model()
one_shot_model = build_one_shot_model()
one_step_model.summary()
one_shot_model.summary()
# Out:
# Model: "Shreya_one_step_ConvLSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)             │ (None, 12, 41, 41, 32)      │          45,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 12, 41, 41, 32)      │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)           │ (None, 12, 41, 41, 32)      │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 12, 41, 41, 32)      │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_2 (ConvLSTM2D)           │ (None, 41, 41, 16)          │          27,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 41, 41, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 41, 41, 7)           │           1,015 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 147,959 (577.96 KB)
#  Trainable params: 147,799 (577.34 KB)
#  Non-trainable params: 160 (640.00 B)
# Model: "Iarla_one_shot_ConvLSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ preceding_12_months (InputLayer)     │ (None, 12, 41, 41, 7)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_3 (ConvLSTM2D)           │ (None, 12, 41, 41, 32)      │          45,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 12, 41, 41, 32)      │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_4 (ConvLSTM2D)           │ (None, 12, 41, 41, 32)      │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 12, 41, 41, 32)      │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_5 (ConvLSTM2D)           │ (None, 41, 41, 16)          │          27,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 41, 41, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 41, 41, 84)          │           1,428 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 41, 41, 12, 7)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ forecast_12_months (Permute)         │ (None, 12, 41, 41, 7)       │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 148,372 (579.58 KB)
#  Trainable params: 148,212 (578.95 KB)
#  Non-trainable params: 160 (640.00 B)

# %% [markdown]
# ## 7. Training/loading the models

# %%
def callbacks_for(path):
    return [
        ModelCheckpoint(path, monitor="val_loss", save_best_only=True, verbose=1),
        ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1),
        EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True, verbose=1),
    ]

if TRAIN_MODELS:
    h1 = one_step_model.fit(
        X1[train1], y1[train1], validation_data=(X1[val1], y1[val1]),
        epochs=EPOCHS, batch_size=ONE_STEP_BATCH_SIZE, shuffle=False,
        callbacks=callbacks_for(ONE_STEP_MODEL_PATH), verbose=1,
    )
    h12 = one_shot_model.fit(
        X12[train12], y12[train12], validation_data=(X12[val12], y12[val12]),
        epochs=EPOCHS, batch_size=ONE_SHOT_BATCH_SIZE, shuffle=False,
        callbacks=callbacks_for(ONE_SHOT_MODEL_PATH), verbose=1,
    )
    histories = {
        "one_step": {k: [float(x) for x in v] for k, v in h1.history.items()},
        "one_shot": {k: [float(x) for x in v] for k, v in h12.history.items()},
    }
    HISTORY_PATH.write_text(json.dumps(histories, indent=2))
else:
    for path in (ONE_STEP_MODEL_PATH, ONE_SHOT_MODEL_PATH):
        if not path.exists():
            raise FileNotFoundError(f"TRAIN_MODELS=False but model does not exist: {path}")

one_step_model = tf.keras.models.load_model(ONE_STEP_MODEL_PATH)
one_shot_model = tf.keras.models.load_model(ONE_SHOT_MODEL_PATH)
print("Loaded best validation models.")
# Out:
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 792ms/step - loss: 1.0416 - mae: 0.7050
# Epoch 1: val_loss improved from None to 0.70599, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 1: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 63s 906ms/step - loss: 0.6815 - mae: 0.5638 - val_loss: 0.7060 - val_mae: 0.5605 - learning_rate: 0.0010
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 783ms/step - loss: 0.4520 - mae: 0.4630
# Epoch 2: val_loss improved from 0.70599 to 0.66053, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 2: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 44s 823ms/step - loss: 0.4183 - mae: 0.4474 - val_loss: 0.6605 - val_mae: 0.5366 - learning_rate: 0.0010
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 0.3915 - mae: 0.4375
# Epoch 3: val_loss improved from 0.66053 to 0.60735, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 3: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 31s 573ms/step - loss: 0.3674 - mae: 0.4246 - val_loss: 0.6073 - val_mae: 0.5149 - learning_rate: 0.0010
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - loss: 0.3548 - mae: 0.4186
# Epoch 4: val_loss improved from 0.60735 to 0.55362, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 4: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 29s 535ms/step - loss: 0.3353 - mae: 0.4071 - val_loss: 0.5536 - val_mae: 0.4976 - learning_rate: 0.0010
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - loss: 0.3315 - mae: 0.4035
# Epoch 5: val_loss improved from 0.55362 to 0.49020, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 5: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 25s 461ms/step - loss: 0.3128 - mae: 0.3915 - val_loss: 0.4902 - val_mae: 0.4723 - learning_rate: 0.0010
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - loss: 0.3097 - mae: 0.3868
# Epoch 6: val_loss improved from 0.49020 to 0.44113, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 6: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 500ms/step - loss: 0.2919 - mae: 0.3744 - val_loss: 0.4411 - val_mae: 0.4487 - learning_rate: 0.0010
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - loss: 0.2883 - mae: 0.3665
# Epoch 7: val_loss improved from 0.44113 to 0.39889, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 7: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 36s 676ms/step - loss: 0.2705 - mae: 0.3532 - val_loss: 0.3989 - val_mae: 0.4287 - learning_rate: 0.0010
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - loss: 0.2711 - mae: 0.3454
# Epoch 8: val_loss improved from 0.39889 to 0.34175, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 8: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 45s 760ms/step - loss: 0.2525 - mae: 0.3319 - val_loss: 0.3418 - val_mae: 0.3972 - learning_rate: 0.0010
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - loss: 0.2408 - mae: 0.3142
# Epoch 9: val_loss improved from 0.34175 to 0.28999, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 9: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 25s 465ms/step - loss: 0.2267 - mae: 0.3037 - val_loss: 0.2900 - val_mae: 0.3608 - learning_rate: 0.0010
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - loss: 0.2229 - mae: 0.2932
# Epoch 10: val_loss improved from 0.28999 to 0.25192, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 10: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 24s 449ms/step - loss: 0.2116 - mae: 0.2859 - val_loss: 0.2519 - val_mae: 0.3240 - learning_rate: 0.0010
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 0.2109 - mae: 0.2778
# Epoch 11: val_loss improved from 0.25192 to 0.22382, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 11: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 25s 456ms/step - loss: 0.2012 - mae: 0.2732 - val_loss: 0.2238 - val_mae: 0.2923 - learning_rate: 0.0010
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 0.2027 - mae: 0.2671
# Epoch 12: val_loss improved from 0.22382 to 0.20941, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 12: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 25s 465ms/step - loss: 0.1937 - mae: 0.2640 - val_loss: 0.2094 - val_mae: 0.2728 - learning_rate: 0.0010
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - loss: 0.1966 - mae: 0.2596
# Epoch 13: val_loss improved from 0.20941 to 0.20157, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 13: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 517ms/step - loss: 0.1881 - mae: 0.2575 - val_loss: 0.2016 - val_mae: 0.2626 - learning_rate: 0.0010
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - loss: 0.2020 - mae: 0.2614
# Epoch 14: val_loss did not improve from 0.20157
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 476ms/step - loss: 0.2378 - mae: 0.2909 - val_loss: 0.5813 - val_mae: 0.5692 - learning_rate: 0.0010
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - loss: 0.2774 - mae: 0.3230
# Epoch 15: val_loss did not improve from 0.20157
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 30s 560ms/step - loss: 0.2402 - mae: 0.2983 - val_loss: 0.2331 - val_mae: 0.2912 - learning_rate: 0.0010
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 0.2082 - mae: 0.2671
# Epoch 16: val_loss did not improve from 0.20157
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 32s 599ms/step - loss: 0.1971 - mae: 0.2616 - val_loss: 0.2046 - val_mae: 0.2565 - learning_rate: 0.0010
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - loss: 0.1959 - mae: 0.2560
# Epoch 17: val_loss improved from 0.20157 to 0.19415, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 17: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 43s 801ms/step - loss: 0.1864 - mae: 0.2523 - val_loss: 0.1942 - val_mae: 0.2487 - learning_rate: 5.0000e-04
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - loss: 0.1870 - mae: 0.2459
# Epoch 18: val_loss improved from 0.19415 to 0.18905, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 18: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 35s 635ms/step - loss: 0.1804 - mae: 0.2463 - val_loss: 0.1891 - val_mae: 0.2408 - learning_rate: 5.0000e-04
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - loss: 0.1834 - mae: 0.2431
# Epoch 19: val_loss improved from 0.18905 to 0.18598, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 19: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 518ms/step - loss: 0.1770 - mae: 0.2436 - val_loss: 0.1860 - val_mae: 0.2362 - learning_rate: 5.0000e-04
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - loss: 0.1802 - mae: 0.2406
# Epoch 20: val_loss improved from 0.18598 to 0.18361, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 20: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 508ms/step - loss: 0.1741 - mae: 0.2412 - val_loss: 0.1836 - val_mae: 0.2328 - learning_rate: 5.0000e-04
# Epoch 21/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - loss: 0.1774 - mae: 0.2384
# Epoch 21: val_loss improved from 0.18361 to 0.18276, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 21: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 29s 542ms/step - loss: 0.1714 - mae: 0.2390 - val_loss: 0.1828 - val_mae: 0.2311 - learning_rate: 5.0000e-04
# Epoch 22/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - loss: 0.1748 - mae: 0.2363
# Epoch 22: val_loss improved from 0.18276 to 0.18157, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 22: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 490ms/step - loss: 0.1688 - mae: 0.2369 - val_loss: 0.1816 - val_mae: 0.2297 - learning_rate: 5.0000e-04
# Epoch 23/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - loss: 0.1723 - mae: 0.2344
# Epoch 23: val_loss did not improve from 0.18157
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 27s 503ms/step - loss: 0.1662 - mae: 0.2348 - val_loss: 0.1830 - val_mae: 0.2299 - learning_rate: 5.0000e-04
# Epoch 24/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 0.1698 - mae: 0.2324
# Epoch 24: val_loss did not improve from 0.18157
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 28s 523ms/step - loss: 0.1637 - mae: 0.2327 - val_loss: 0.1825 - val_mae: 0.2295 - learning_rate: 5.0000e-04
# Epoch 25/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.1673 - mae: 0.2304
# Epoch 25: val_loss did not improve from 0.18157
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 30s 565ms/step - loss: 0.1611 - mae: 0.2305 - val_loss: 0.1828 - val_mae: 0.2298 - learning_rate: 5.0000e-04
# Epoch 26/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.1636 - mae: 0.2269
# Epoch 26: val_loss improved from 0.18157 to 0.17848, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
#
# Epoch 26: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_step_convlstm.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 31s 584ms/step - loss: 0.1570 - mae: 0.2259 - val_loss: 0.1785 - val_mae: 0.2271 - learning_rate: 2.5000e-04
# Epoch 27/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - loss: 0.1611 - mae: 0.2251
# Epoch 27: val_loss did not improve from 0.17848
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 35s 654ms/step - loss: 0.1553 - mae: 0.2246 - val_loss: 0.1786 - val_mae: 0.2259 - learning_rate: 2.5000e-04
# Epoch 28/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 671ms/step - loss: 0.1597 - mae: 0.2238
# Epoch 28: val_loss did not improve from 0.17848
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 721ms/step - loss: 0.1539 - mae: 0.2234 - val_loss: 0.1786 - val_mae: 0.2254 - learning_rate: 2.5000e-04
# Epoch 29/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - loss: 0.1583 - mae: 0.2226
# Epoch 29: val_loss did not improve from 0.17848
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 36s 663ms/step - loss: 0.1525 - mae: 0.2221 - val_loss: 0.1786 - val_mae: 0.2251 - learning_rate: 2.5000e-04
# Epoch 30/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 682ms/step - loss: 0.1562 - mae: 0.2208
# Epoch 30: val_loss did not improve from 0.17848
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 40s 745ms/step - loss: 0.1505 - mae: 0.2202 - val_loss: 0.1800 - val_mae: 0.2317 - learning_rate: 1.2500e-04
# Epoch 31/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 846ms/step - loss: 0.1552 - mae: 0.2206
# Epoch 31: val_loss did not improve from 0.17848
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 50s 927ms/step - loss: 0.1495 - mae: 0.2194 - val_loss: 0.1803 - val_mae: 0.2318 - learning_rate: 1.2500e-04
# Epoch 32/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.1543 - mae: 0.2197
# Epoch 32: val_loss did not improve from 0.17848
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.1486 - mae: 0.2186 - val_loss: 0.1805 - val_mae: 0.2318 - learning_rate: 1.2500e-04
# Epoch 33/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.1531 - mae: 0.2184
# Epoch 33: val_loss did not improve from 0.17848
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - loss: 0.1472 - mae: 0.2170 - val_loss: 0.1786 - val_mae: 0.2258 - learning_rate: 6.2500e-05
# Epoch 34/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.1523 - mae: 0.2167
# Epoch 34: val_loss did not improve from 0.17848
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - loss: 0.1467 - mae: 0.2163 - val_loss: 0.1787 - val_mae: 0.2260 - learning_rate: 6.2500e-05
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 26.
# Epoch 1/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - loss: 0.8771 - mae: 0.6456
# Epoch 1: val_loss improved from None to 0.75082, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 1: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 92s 661ms/step - loss: 0.7010 - mae: 0.5711 - val_loss: 0.7508 - val_mae: 0.6104 - learning_rate: 0.0010
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - loss: 0.5557 - mae: 0.5069
# Epoch 2: val_loss improved from 0.75082 to 0.63811, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 2: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 62s 602ms/step - loss: 0.5305 - mae: 0.5013 - val_loss: 0.6381 - val_mae: 0.5648 - learning_rate: 0.0010
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 629ms/step - loss: 0.5234 - mae: 0.4965
# Epoch 3: val_loss improved from 0.63811 to 0.55950, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 3: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 68s 665ms/step - loss: 0.5062 - mae: 0.4930 - val_loss: 0.5595 - val_mae: 0.5257 - learning_rate: 0.0010
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - loss: 0.5104 - mae: 0.4917
# Epoch 4: val_loss improved from 0.55950 to 0.50315, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 4: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 65s 632ms/step - loss: 0.4948 - mae: 0.4889 - val_loss: 0.5032 - val_mae: 0.4978 - learning_rate: 0.0010
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - loss: 0.5008 - mae: 0.4882
# Epoch 5: val_loss improved from 0.50315 to 0.47584, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 5: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 65s 631ms/step - loss: 0.4860 - mae: 0.4856 - val_loss: 0.4758 - val_mae: 0.4812 - learning_rate: 0.0010
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - loss: 0.4933 - mae: 0.4857
# Epoch 6: val_loss improved from 0.47584 to 0.46469, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 6: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 64s 624ms/step - loss: 0.4788 - mae: 0.4833 - val_loss: 0.4647 - val_mae: 0.4731 - learning_rate: 0.0010
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - loss: 0.4877 - mae: 0.4840
# Epoch 7: val_loss improved from 0.46469 to 0.45906, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 7: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 75s 725ms/step - loss: 0.4726 - mae: 0.4813 - val_loss: 0.4591 - val_mae: 0.4669 - learning_rate: 0.0010
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - loss: 0.4813 - mae: 0.4819
# Epoch 8: val_loss did not improve from 0.45906
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 68s 656ms/step - loss: 0.4670 - mae: 0.4795 - val_loss: 0.4599 - val_mae: 0.4647 - learning_rate: 0.0010
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 857ms/step - loss: 0.4761 - mae: 0.4806
# Epoch 9: val_loss did not improve from 0.45906
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 91s 885ms/step - loss: 0.4627 - mae: 0.4783 - val_loss: 0.4644 - val_mae: 0.4629 - learning_rate: 0.0010
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - loss: 0.4721 - mae: 0.4797
# Epoch 10: val_loss improved from 0.45906 to 0.44535, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 10: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 66s 637ms/step - loss: 0.4587 - mae: 0.4772 - val_loss: 0.4454 - val_mae: 0.4538 - learning_rate: 0.0010
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 619ms/step - loss: 0.4681 - mae: 0.4783
# Epoch 11: val_loss improved from 0.44535 to 0.43258, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 11: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 68s 654ms/step - loss: 0.4547 - mae: 0.4760 - val_loss: 0.4326 - val_mae: 0.4446 - learning_rate: 0.0010
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - loss: 0.4630 - mae: 0.4770
# Epoch 12: val_loss improved from 0.43258 to 0.41566, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 12: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 65s 628ms/step - loss: 0.4499 - mae: 0.4744 - val_loss: 0.4157 - val_mae: 0.4306 - learning_rate: 0.0010
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - loss: 0.4580 - mae: 0.4755
# Epoch 13: val_loss improved from 0.41566 to 0.40737, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 13: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 63s 613ms/step - loss: 0.4460 - mae: 0.4732 - val_loss: 0.4074 - val_mae: 0.4226 - learning_rate: 0.0010
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.4544 - mae: 0.4744
# Epoch 14: val_loss improved from 0.40737 to 0.39837, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 14: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 21s 199ms/step - loss: 0.4431 - mae: 0.4723 - val_loss: 0.3984 - val_mae: 0.4131 - learning_rate: 0.0010
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - loss: 0.4504 - mae: 0.4732
# Epoch 15: val_loss improved from 0.39837 to 0.39383, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 15: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 22s 214ms/step - loss: 0.4399 - mae: 0.4713 - val_loss: 0.3938 - val_mae: 0.4061 - learning_rate: 0.0010
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.4484 - mae: 0.4722
# Epoch 16: val_loss improved from 0.39383 to 0.37947, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 16: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 23s 221ms/step - loss: 0.4360 - mae: 0.4699 - val_loss: 0.3795 - val_mae: 0.3935 - learning_rate: 0.0010
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.4429 - mae: 0.4707
# Epoch 17: val_loss improved from 0.37947 to 0.37386, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 17: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 23s 224ms/step - loss: 0.4323 - mae: 0.4689 - val_loss: 0.3739 - val_mae: 0.3864 - learning_rate: 0.0010
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 0.4380 - mae: 0.4690
# Epoch 18: val_loss improved from 0.37386 to 0.36589, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 18: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 24s 229ms/step - loss: 0.4281 - mae: 0.4674 - val_loss: 0.3659 - val_mae: 0.3788 - learning_rate: 0.0010
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 0.4353 - mae: 0.4683
# Epoch 19: val_loss improved from 0.36589 to 0.35455, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 19: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 24s 230ms/step - loss: 0.4252 - mae: 0.4665 - val_loss: 0.3546 - val_mae: 0.3713 - learning_rate: 0.0010
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 0.4316 - mae: 0.4673
# Epoch 20: val_loss improved from 0.35455 to 0.35301, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 20: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 24s 231ms/step - loss: 0.4222 - mae: 0.4657 - val_loss: 0.3530 - val_mae: 0.3666 - learning_rate: 0.0010
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 0.4294 - mae: 0.4666
# Epoch 21: val_loss improved from 0.35301 to 0.34876, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 21: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 24s 234ms/step - loss: 0.4197 - mae: 0.4650 - val_loss: 0.3488 - val_mae: 0.3628 - learning_rate: 0.0010
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 0.4269 - mae: 0.4658
# Epoch 22: val_loss improved from 0.34876 to 0.34361, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 22: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 24s 236ms/step - loss: 0.4176 - mae: 0.4644 - val_loss: 0.3436 - val_mae: 0.3592 - learning_rate: 0.0010
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 0.4239 - mae: 0.4649
# Epoch 23: val_loss did not improve from 0.34361
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 25s 238ms/step - loss: 0.4152 - mae: 0.4637 - val_loss: 0.3468 - val_mae: 0.3560 - learning_rate: 0.0010
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - loss: 0.4216 - mae: 0.4643
# Epoch 24: val_loss did not improve from 0.34361
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 29s 279ms/step - loss: 0.4131 - mae: 0.4631 - val_loss: 0.3479 - val_mae: 0.3543 - learning_rate: 0.0010
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 0.4203 - mae: 0.4637
# Epoch 25: val_loss did not improve from 0.34361
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 36s 352ms/step - loss: 0.4114 - mae: 0.4623 - val_loss: 0.3470 - val_mae: 0.3510 - learning_rate: 0.0010
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - loss: 0.4165 - mae: 0.4621
# Epoch 26: val_loss improved from 0.34361 to 0.33475, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 26: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 375ms/step - loss: 0.4076 - mae: 0.4605 - val_loss: 0.3348 - val_mae: 0.3433 - learning_rate: 5.0000e-04
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - loss: 0.4128 - mae: 0.4605
# Epoch 27: val_loss improved from 0.33475 to 0.33119, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 27: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 399ms/step - loss: 0.4042 - mae: 0.4595 - val_loss: 0.3312 - val_mae: 0.3407 - learning_rate: 5.0000e-04
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - loss: 0.4099 - mae: 0.4596
# Epoch 28: val_loss improved from 0.33119 to 0.33033, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 28: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 49s 478ms/step - loss: 0.4018 - mae: 0.4588 - val_loss: 0.3303 - val_mae: 0.3393 - learning_rate: 5.0000e-04
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - loss: 0.4076 - mae: 0.4590
# Epoch 29: val_loss improved from 0.33033 to 0.32917, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 29: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 66s 640ms/step - loss: 0.3998 - mae: 0.4582 - val_loss: 0.3292 - val_mae: 0.3376 - learning_rate: 5.0000e-04
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - loss: 0.4057 - mae: 0.4584
# Epoch 30: val_loss improved from 0.32917 to 0.32768, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 30: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 66s 639ms/step - loss: 0.3981 - mae: 0.4577 - val_loss: 0.3277 - val_mae: 0.3359 - learning_rate: 5.0000e-04
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - loss: 0.4040 - mae: 0.4579
# Epoch 31: val_loss improved from 0.32768 to 0.32629, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 31: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 66s 636ms/step - loss: 0.3965 - mae: 0.4572 - val_loss: 0.3263 - val_mae: 0.3346 - learning_rate: 5.0000e-04
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - loss: 0.4023 - mae: 0.4574
# Epoch 32: val_loss improved from 0.32629 to 0.32509, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 32: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 64s 616ms/step - loss: 0.3949 - mae: 0.4568 - val_loss: 0.3251 - val_mae: 0.3335 - learning_rate: 5.0000e-04
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - loss: 0.4007 - mae: 0.4570
# Epoch 33: val_loss improved from 0.32509 to 0.32426, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 33: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 65s 631ms/step - loss: 0.3935 - mae: 0.4563 - val_loss: 0.3243 - val_mae: 0.3326 - learning_rate: 5.0000e-04
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - loss: 0.3991 - mae: 0.4565
# Epoch 34: val_loss improved from 0.32426 to 0.32366, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 34: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 65s 625ms/step - loss: 0.3920 - mae: 0.4559 - val_loss: 0.3237 - val_mae: 0.3319 - learning_rate: 5.0000e-04
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - loss: 0.3976 - mae: 0.4561
# Epoch 35: val_loss improved from 0.32366 to 0.32335, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 35: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 64s 620ms/step - loss: 0.3905 - mae: 0.4555 - val_loss: 0.3233 - val_mae: 0.3311 - learning_rate: 5.0000e-04
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 0.3960 - mae: 0.4557
# Epoch 36: val_loss improved from 0.32335 to 0.32327, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 36: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 62s 603ms/step - loss: 0.3891 - mae: 0.4551 - val_loss: 0.3233 - val_mae: 0.3306 - learning_rate: 5.0000e-04
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - loss: 0.3945 - mae: 0.4553
# Epoch 37: val_loss did not improve from 0.32327
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 66s 633ms/step - loss: 0.3876 - mae: 0.4547 - val_loss: 0.3233 - val_mae: 0.3300 - learning_rate: 5.0000e-04
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 644ms/step - loss: 0.3929 - mae: 0.4549
# Epoch 38: val_loss did not improve from 0.32327
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 72s 698ms/step - loss: 0.3862 - mae: 0.4543 - val_loss: 0.3236 - val_mae: 0.3297 - learning_rate: 5.0000e-04
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - loss: 0.3916 - mae: 0.4542
# Epoch 39: val_loss improved from 0.32327 to 0.32148, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 39: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 81s 681ms/step - loss: 0.3848 - mae: 0.4536 - val_loss: 0.3215 - val_mae: 0.3272 - learning_rate: 2.5000e-04
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - loss: 0.3908 - mae: 0.4537
# Epoch 40: val_loss did not improve from 0.32148
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 64s 621ms/step - loss: 0.3838 - mae: 0.4533 - val_loss: 0.3221 - val_mae: 0.3271 - learning_rate: 2.5000e-04
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - loss: 0.3896 - mae: 0.4534
# Epoch 41: val_loss did not improve from 0.32148
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 60s 581ms/step - loss: 0.3828 - mae: 0.4530 - val_loss: 0.3223 - val_mae: 0.3264 - learning_rate: 2.5000e-04
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - loss: 0.3885 - mae: 0.4531
# Epoch 42: val_loss did not improve from 0.32148
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 60s 578ms/step - loss: 0.3818 - mae: 0.4527 - val_loss: 0.3227 - val_mae: 0.3260 - learning_rate: 2.5000e-04
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.3880 - mae: 0.4528
# Epoch 43: val_loss improved from 0.32148 to 0.31840, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 43: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 59s 573ms/step - loss: 0.3814 - mae: 0.4523 - val_loss: 0.3184 - val_mae: 0.3219 - learning_rate: 1.2500e-04
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - loss: 0.3872 - mae: 0.4525
# Epoch 44: val_loss improved from 0.31840 to 0.31781, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 44: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 63s 607ms/step - loss: 0.3805 - mae: 0.4520 - val_loss: 0.3178 - val_mae: 0.3215 - learning_rate: 1.2500e-04
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - loss: 0.3863 - mae: 0.4523
# Epoch 45: val_loss improved from 0.31781 to 0.31754, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 45: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 62s 600ms/step - loss: 0.3798 - mae: 0.4518 - val_loss: 0.3175 - val_mae: 0.3212 - learning_rate: 1.2500e-04
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - loss: 0.3855 - mae: 0.4521
# Epoch 46: val_loss improved from 0.31754 to 0.31738, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 46: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 63s 609ms/step - loss: 0.3792 - mae: 0.4516 - val_loss: 0.3174 - val_mae: 0.3209 - learning_rate: 1.2500e-04
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.3849 - mae: 0.4519
# Epoch 47: val_loss improved from 0.31738 to 0.31732, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 47: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 70s 672ms/step - loss: 0.3786 - mae: 0.4515 - val_loss: 0.3173 - val_mae: 0.3207 - learning_rate: 1.2500e-04
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - loss: 0.3843 - mae: 0.4518
# Epoch 48: val_loss did not improve from 0.31732
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 64s 622ms/step - loss: 0.3780 - mae: 0.4513 - val_loss: 0.3173 - val_mae: 0.3205 - learning_rate: 1.2500e-04
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - loss: 0.3837 - mae: 0.4516
# Epoch 49: val_loss did not improve from 0.31732
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 60s 577ms/step - loss: 0.3775 - mae: 0.4512 - val_loss: 0.3173 - val_mae: 0.3203 - learning_rate: 1.2500e-04
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 626ms/step - loss: 0.3834 - mae: 0.4514
# Epoch 50: val_loss improved from 0.31732 to 0.31597, saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
#
# Epoch 50: finished saving model to C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\best_one_shot_12month_convlstm.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 71s 688ms/step - loss: 0.3771 - mae: 0.4508 - val_loss: 0.3160 - val_mae: 0.3187 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 50.
# Loaded best validation models.

# %% [markdown]
# ## 8. Generate all four forecasts
#
# The adapted methods are started with the same 12 observed months ending December 1981, after which only their own predictions enter their input windows.

# %%
forecast_times = pd.date_range(FORECAST_START, FORECAST_END, freq="MS")
time_to_index = {timestamp: i for i, timestamp in enumerate(times)}

def observed_window_before(target_time):
    target_i = time_to_index[target_time]
    window = data_scaled[target_i - LOOKBACK:target_i]
    window_times = times[target_i - LOOKBACK:target_i]
    if len(window) != LOOKBACK or not is_consecutive(window_times):
        raise ValueError(f"Invalid observed input window before {target_time:%Y-%m}")
    return window.copy()

# Shreya
shreya_scaled = np.empty((len(forecast_times), n_lat, n_lon, n_features), np.float32)
shreya_window = observed_window_before(FORECAST_START)
for i, target_time in enumerate(forecast_times):
    preceding = pd.date_range(target_time - pd.DateOffset(months=LOOKBACK), periods=LOOKBACK, freq="MS")
    if all(timestamp in time_to_index for timestamp in preceding):
        shreya_window = np.stack([data_scaled[time_to_index[timestamp]] for timestamp in preceding])
    prediction = one_step_model.predict(shreya_window[None, ...], verbose=0)[0]
    shreya_scaled[i] = prediction
    shreya_window = np.concatenate([shreya_window[1:], prediction[None, ...]], axis=0)

# Adapted Shreya
adapted_shreya_scaled = np.empty_like(shreya_scaled)
recursive_window = observed_window_before(FORECAST_START)
for i in range(len(forecast_times)):
    prediction = one_step_model.predict(recursive_window[None, ...], verbose=0)[0]
    adapted_shreya_scaled[i] = prediction
    recursive_window = np.concatenate([recursive_window[1:], prediction[None, ...]], axis=0)

# Calendar year starts for 12month blocks
block_starts = pd.date_range(FORECAST_START, FORECAST_END, freq="YS")
if len(forecast_times) % HORIZON:
    raise ValueError("Forecast period must contain a whole number of 12-month blocks.")

# Iarla
iarla_blocks = []
iarla_input = observed_window_before(FORECAST_START)
for block_start in block_starts:
    preceding = pd.date_range(block_start - pd.DateOffset(months=LOOKBACK), periods=LOOKBACK, freq="MS")
    if all(timestamp in time_to_index for timestamp in preceding):
        iarla_input = np.stack([data_scaled[time_to_index[timestamp]] for timestamp in preceding])
    prediction_block = one_shot_model.predict(iarla_input[None, ...], verbose=0)[0]
    iarla_blocks.append(prediction_block)
    iarla_input = prediction_block.copy()
iarla_scaled = np.concatenate(iarla_blocks, axis=0)

# Adapted Iarla
adapted_iarla_blocks = []
recursive_block = observed_window_before(FORECAST_START)
for _ in block_starts:
    prediction_block = one_shot_model.predict(recursive_block[None, ...], verbose=0)[0]
    adapted_iarla_blocks.append(prediction_block)
    recursive_block = prediction_block.copy()
adapted_iarla_scaled = np.concatenate(adapted_iarla_blocks, axis=0)

truth_scaled = np.full((len(forecast_times), n_lat, n_lon, n_features), np.nan, np.float32)
for i, timestamp in enumerate(forecast_times):
    if timestamp in time_to_index:
        truth_scaled[i] = data_scaled[time_to_index[timestamp]]
truth = inverse_scale(truth_scaled)
predictions = {
    "Shreya (observed inputs)": inverse_scale(shreya_scaled),
    "Adapted Shreya (recursive)": inverse_scale(adapted_shreya_scaled),
    "Iarla (observed blocks)": inverse_scale(iarla_scaled),
    "Adapted Iarla (recursive blocks)": inverse_scale(adapted_iarla_scaled),
}

for name, values in predictions.items():
    assert values.shape == truth.shape, (name, values.shape, truth.shape)
    assert np.isfinite(values).all(), f"Non-finite predictions in {name}"

print("Forecast dates:", forecast_times[0], "to", forecast_times[-1])
print("Each result shape:", truth.shape)
# Out:
# Forecast dates: 1982-01-01 00:00:00 to 2025-12-01 00:00:00
# Each result shape: (528, 41, 41, 7)

# %% [markdown]
# ## 8.5. Change primary variable

# %%
PRIMARY_FEATURE = "salinity"

if PRIMARY_FEATURE not in features:
    raise ValueError(
        f"{PRIMARY_FEATURE!r} is unavailable. Choose from: {features}"
    )

print("Selected feature:", PRIMARY_FEATURE)
# Out:
# Selected feature: salinity

# %% [markdown]
# ## 9. Direct monthly comparison

# %%
primary_index = features.index(PRIMARY_FEATURE)

def box_mean(values):
    return np.nanmean(values[..., primary_index], axis=(1, 2))

monthly_series = {"Actual": box_mean(truth)}
monthly_series.update({name: box_mean(values) for name, values in predictions.items()})
monthly_df = pd.DataFrame(monthly_series, index=forecast_times)
monthly_df.index.name = "time"

colors = {
    "Actual": "black",
    "Shreya (observed inputs)": "#1f77b4",
    "Adapted Shreya (recursive)": "#17becf",
    "Iarla (observed blocks)": "#d62728",
    "Adapted Iarla (recursive blocks)": "#ff7f0e",
}

fig, ax = plt.subplots(figsize=(19, 7))
for name in monthly_df.columns:
    ax.plot(monthly_df.index, monthly_df[name], label=name, color=colors[name],
            linewidth=2.2 if name == "Actual" else 1.15, alpha=0.95 if name == "Actual" else 0.82)
ax.set(title=f"Monthly box-mean {PRIMARY_FEATURE.upper()}: four ConvLSTM methods vs actual",
       xlabel="Time", ylabel=f"Monthly mean {PRIMARY_FEATURE.upper()}")
ax.grid(alpha=0.25)
ax.legend(ncol=3, frameon=False)
fig.tight_layout()
fig.savefig(OUTPUT_DIR / "monthly_four_method_comparison.png", dpi=200, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 10. Annual avg comparison

# %%
annual_df = monthly_df.resample("YS").mean()

fig, ax = plt.subplots(figsize=(16, 7))
for name in annual_df.columns:
    ax.plot(annual_df.index.year, annual_df[name], marker="o", markersize=3.5,
            label=name, color=colors[name], linewidth=2.4 if name == "Actual" else 1.6)
ax.set(title=f"Annual-average box-mean {PRIMARY_FEATURE.upper()}: four ConvLSTM methods vs actual",
       xlabel="Year", ylabel=f"Annual mean {PRIMARY_FEATURE.upper()}")
ax.grid(alpha=0.25)
ax.legend(ncol=3, frameon=False)
fig.tight_layout()
fig.savefig(OUTPUT_DIR / "annual_four_method_comparison.png", dpi=200, bbox_inches="tight")
plt.show()

display(annual_df)
# Out:
#                Actual  Shreya (observed inputs)  Adapted Shreya (recursive)  \
# time
# 1982-01-01  20.450615                 20.262285                   20.233923
# 1983-01-01  20.623476                 20.405876                   20.257879
# 1984-01-01  20.527903                 20.352522                   20.991587
# 1985-01-01  20.229187                 20.206160                   21.349045
# 1986-01-01  20.644888                 20.336744                   20.756998
# 1987-01-01  20.568569                 20.466070                   20.563065
# 1988-01-01  20.844584                 20.547598                   20.379816
# 1989-01-01  20.769705                 20.565178                   20.228144
# 1990-01-01  20.898237                 20.605408                   19.972952
# 1991-01-01  21.068151                 20.831642                   19.802471
# 1992-01-01  20.817814                 20.702658                   19.607338
# 1993-01-01  20.847734                 20.631607                   19.482344
# 1994-01-01  20.988369                 20.669563                   19.459208
# 1995-01-01  20.916748                 20.796637                   19.406736
# 1996-01-01  20.790689                 20.503853                   19.324858
# 1997-01-01  20.559710                 20.406717                   19.264196
# 1998-01-01  21.221331                 20.775253                   19.342985
# 1999-01-01  21.335762                 21.012770                   19.320040
# 2000-01-01  21.373154                 21.093979                   19.330538
# 2001-01-01  21.069883                 20.867241                   19.362078
# 2002-01-01  20.842775                 20.600216                   19.360554
# 2003-01-01  21.130283                 20.787481                   19.456781
# 2004-01-01  21.111067                 20.892111                   19.516735
# 2005-01-01  21.059372                 20.881155                   19.566692
# 2006-01-01  21.159220                 20.854559                   19.539331
# 2007-01-01  21.053608                 20.828573                   19.530651
# 2008-01-01  21.374979                 20.996660                   19.441660
# 2009-01-01  21.044874                 20.918413                   19.359715
# 2010-01-01  20.778408                 20.585421                   19.325672
# 2011-01-01  20.823687                 20.470732                   19.387886
# 2012-01-01  21.141237                 20.762890                   19.328226
# 2013-01-01  21.069050                 20.746828                   19.341894
# 2014-01-01  21.098595                 20.758471                   19.266947
# 2015-01-01  21.199856                 20.946974                   19.326258
# 2016-01-01  21.141600                 20.869638                   19.356932
# 2017-01-01  21.147156                 20.876360                   19.395378
# 2018-01-01  21.491720                 21.142330                   19.398378
# 2019-01-01        NaN                 20.886183                   19.401773
# 2020-01-01        NaN                 20.832588                   19.346270
# 2021-01-01        NaN                 20.895763                   19.322292
# 2022-01-01        NaN                 21.003443                   19.334414
# 2023-01-01        NaN                 21.010027                   19.388676
# 2024-01-01        NaN                 20.658854                   19.382677
# 2025-01-01        NaN                 20.300097                   19.395065
#
#             Iarla (observed blocks)  Adapted Iarla (recursive blocks)
# time
# 1982-01-01                20.666849                         20.666849
# 1983-01-01                20.577787                         20.729382
# 1984-01-01                20.686644                         20.864790
# 1985-01-01                20.683647                         20.978970
# 1986-01-01                20.475372                         21.104258
# 1987-01-01                20.750364                         21.222481
# 1988-01-01                20.658850                         21.328728
# 1989-01-01                20.828030                         21.417158
# 1990-01-01                20.861036                         21.497818
# 1991-01-01                20.927078                         21.592340
# 1992-01-01                21.036633                         21.637932
# 1993-01-01                20.899155                         21.679260
# 1994-01-01                20.904663                         21.737864
# 1995-01-01                21.021166                         21.797659
# 1996-01-01                21.020563                         21.855909
# 1997-01-01                20.825937                         21.872438
# 1998-01-01                20.737007                         21.933235
# 1999-01-01                21.031221                         21.968859
# 2000-01-01                21.206358                         22.006105
# 2001-01-01                21.380217                         22.049177
# 2002-01-01                21.092283                         22.092613
# 2003-01-01                20.986933                         22.146162
# 2004-01-01                21.108570                         22.176123
# 2005-01-01                21.262827                         22.185303
# 2006-01-01                21.231455                         22.215532
# 2007-01-01                21.196009                         22.243307
# 2008-01-01                21.101549                         22.292887
# 2009-01-01                21.249943                         22.344782
# 2010-01-01                21.041515                         22.407122
# 2011-01-01                20.666430                         22.467932
# 2012-01-01                20.692774                         22.527033
# 2013-01-01                20.989674                         22.612200
# 2014-01-01                20.910711                         22.682817
# 2015-01-01                21.013563                         22.771852
# 2016-01-01                21.102873                         22.859446
# 2017-01-01                21.136391                         22.928259
# 2018-01-01                21.195272                         22.979040
# 2019-01-01                21.479712                         23.009102
# 2020-01-01                21.467283                         23.046770
# 2021-01-01                21.571419                         23.079477
# 2022-01-01                21.642876                         23.108541
# 2023-01-01                21.722807                         23.134254
# 2024-01-01                21.782837                         23.151220
# 2025-01-01                21.875299                         23.169067

# %% [markdown]
# ## 11. Summary metrics and saved prediction data

# %%
metric_rows = []
actual_monthly = monthly_df["Actual"].to_numpy()
for name in predictions:
    predicted_monthly = monthly_df[name].to_numpy()
    monthly_valid = np.isfinite(actual_monthly) & np.isfinite(predicted_monthly)
    annual_actual = annual_df["Actual"].to_numpy()
    annual_predicted = annual_df[name].to_numpy()
    annual_valid = np.isfinite(annual_actual) & np.isfinite(annual_predicted)
    metric_rows.append({
        "method": name,
        "comparison_start": forecast_times[monthly_valid][0],
        "comparison_end": forecast_times[monthly_valid][-1],
        "monthly_MAE": mean_absolute_error(actual_monthly[monthly_valid], predicted_monthly[monthly_valid]),
        "monthly_RMSE": np.sqrt(mean_squared_error(actual_monthly[monthly_valid], predicted_monthly[monthly_valid])),
        "monthly_R2": r2_score(actual_monthly[monthly_valid], predicted_monthly[monthly_valid]),
        "annual_MAE": mean_absolute_error(annual_actual[annual_valid], annual_predicted[annual_valid]),
        "annual_RMSE": np.sqrt(mean_squared_error(annual_actual[annual_valid], annual_predicted[annual_valid])),
        "annual_R2": r2_score(annual_actual[annual_valid], annual_predicted[annual_valid]),
    })
metrics_df = pd.DataFrame(metric_rows).sort_values("monthly_RMSE")
display(metrics_df)
metrics_df.to_csv(METRICS_PATH, index=False)
monthly_df.to_csv(OUTPUT_DIR / "monthly_box_mean_comparison.csv")
annual_df.to_csv(OUTPUT_DIR / "annual_box_mean_comparison.csv")

safe_names = {
    "Shreya (observed inputs)": "shreya_observed_inputs",
    "Adapted Shreya (recursive)": "adapted_shreya_recursive",
    "Iarla (observed blocks)": "iarla_observed_blocks",
    "Adapted Iarla (recursive blocks)": "adapted_iarla_recursive_blocks",
}
data_vars = {"actual": (("time", "lat", "lon", "feature"), truth)}
for label, values in predictions.items():
    data_vars[safe_names[label]] = (("time", "lat", "lon", "feature"), values)

prediction_ds = xr.Dataset(
    data_vars=data_vars,
    coords={"time": forecast_times, "lat": lats, "lon": lons, "feature": features},
    attrs={
        "description": "Four ConvLSTM forecasts through December 2025; actual data are NaN after the tensor ends",
        "training_targets": "before 1977-01",
        "validation_targets": "1977-01 through 1981-12",
    },
)
prediction_ds.to_netcdf(PREDICTIONS_PATH, engine="h5netcdf")
print("Saved outputs to:", OUTPUT_DIR)
print("Prediction tensor:", PREDICTIONS_PATH)
# Out:
#                              method comparison_start comparison_end  \
# 0          Shreya (observed inputs)       1982-01-01     2018-12-01
# 2           Iarla (observed blocks)       1982-01-01     2018-12-01
# 3  Adapted Iarla (recursive blocks)       1982-01-01     2018-12-01
# 1        Adapted Shreya (recursive)       1982-01-01     2018-12-01
#
#    monthly_MAE  monthly_RMSE  monthly_R2  annual_MAE  annual_RMSE  annual_R2
# 0     0.386723      0.494879    0.962677    0.250147     0.265683   0.084329
# 2     0.923712      1.085933    0.820286    0.184581     0.218875   0.378551
# 3     1.980265      2.298154    0.195115    0.990801     1.084549 -14.258455
# 1     2.207215      2.825926   -0.217019    1.358633     1.473336 -27.158899
# Saved outputs to: C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025
# Prediction tensor: C:\Users\itsna\OneDrive\Desktop\MSc_Work\DataSets\Processed\ConvLSTM_four_method_1982_2025\four_method_predictions.nc

# %%
# Shared plotting function

def plot_method_full_range(
    method_name,
    prediction_color,
    file_prefix,
):
    # Actual monthly spatial box avg
    actual_full_monthly_values = np.nanmean(
        data_filled[..., primary_index],
        axis=(1, 2),
    )

    actual_full_monthly = pd.Series(
        actual_full_monthly_values,
        index=times,
        name="Actual SST",
    )

    # Predictions (January 1982 through December 2025)
    predicted_monthly = monthly_df[method_name].copy()

    # Annual averages
    actual_full_annual = actual_full_monthly.resample("YS").mean()
    predicted_annual = predicted_monthly.resample("YS").mean()

    actual_end = actual_full_monthly.dropna().index.max()
    forecast_end = predicted_monthly.dropna().index.max()

    # Monthly SST
    fig, ax = plt.subplots(figsize=(20, 7))

    ax.plot(
        actual_full_monthly.index,
        actual_full_monthly.values,
        color="#1f77b4",
        linewidth=1.5,
        label="Actual SST",
    )

    ax.plot(
        predicted_monthly.index,
        predicted_monthly.values,
        color=prediction_color,
        linewidth=1.7,
        linestyle="--",
        label=method_name,
    )


    ax.set_title(
        f"Monthly Box-Mean SST Across the Study Region — {method_name}"
    )
    ax.set_xlabel("Time")
    ax.set_ylabel("Monthly box-mean SST (°C)")
    ax.set_xlim(
        actual_full_monthly.index.min(),
        pd.Timestamp("2025-12-31"),
    )
    ax.grid(alpha=0.25)
    ax.legend(frameon=False, ncol=3)
    fig.tight_layout()

    fig.savefig(
        OUTPUT_DIR / f"{file_prefix}_monthly_full_range.png",
        dpi=200,
        bbox_inches="tight",
    )

    plt.show()

    # Annual SST
    fig, ax = plt.subplots(figsize=(17, 7))

    ax.plot(
        actual_full_annual.index.year,
        actual_full_annual.values,
        color="#1f77b4",
        marker="o",
        markersize=3,
        linewidth=2,
        label="Actual SST",
    )

    ax.plot(
        predicted_annual.index.year,
        predicted_annual.values,
        color=prediction_color,
        marker="s",
        markersize=4,
        linewidth=2,
        linestyle="--",
        label=method_name,
    )

    ax.set_title(
        f"Annual Mean SST Across the Study Region — {method_name}"
    )
    ax.set_xlabel("Year")
    ax.set_ylabel("Annual box-mean SST (°C)")
    ax.set_xlim(
        actual_full_annual.index.year.min() - 1,
        2026,
    )
    ax.grid(alpha=0.25)
    ax.legend(frameon=False, ncol=3)
    fig.tight_layout()

    fig.savefig(
        OUTPUT_DIR / f"{file_prefix}_annual_full_range.png",
        dpi=200,
        bbox_inches="tight",
    )

    plt.show()

    print(
        f"Actual data: {actual_full_monthly.index.min():%Y-%m} "
        f"to {actual_end:%Y-%m}"
    )
    print(
        f"{method_name}: {predicted_monthly.index.min():%Y-%m} "
        f"to {forecast_end:%Y-%m}"
    )

# %%
# Shreya method

plot_method_full_range(
    method_name="Shreya (observed inputs)",
    prediction_color="#ff7f0e",
    file_prefix="shreya_observed",
)
# Out:
# Actual data: 1958-01 to 2018-12
# Shreya (observed inputs): 1982-01 to 2025-12

# %%
# Adapted Shreya

plot_method_full_range(
    method_name="Adapted Shreya (recursive)",
    prediction_color="#17becf",
    file_prefix="adapted_shreya_recursive",
)
# Out:
# Actual data: 1958-01 to 2018-12
# Adapted Shreya (recursive): 1982-01 to 2025-12

# %%
# Iarla method

plot_method_full_range(
    method_name="Iarla (observed blocks)",
    prediction_color="#d62728",
    file_prefix="iarla_observed",
)
# Out:
# Actual data: 1958-01 to 2018-12
# Iarla (observed blocks): 1982-01 to 2025-12

# %%
# Adapted Iarla method

plot_method_full_range(
    method_name="Adapted Iarla (recursive blocks)",
    prediction_color="#ff7f0e",
    file_prefix="adapted_iarla_recursive",
)
# Out:
# Actual data: 1958-01 to 2018-12
# Adapted Iarla (recursive blocks): 1982-01 to 2025-12
